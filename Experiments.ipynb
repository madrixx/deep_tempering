# %%
import tensorflow as tf
import numpy as np
from time import time
from simulation.simulator import Simulator
from simulation.architectures.mnist_architectures import nn_mnist_architecture
from simulation.architectures.mnist_architectures import cnn_mnist_architecture
from simulation.architectures.cifar10_architectures import cnn_cifar10_architecture3
from simulation.architectures.cifar10_architectures import cnn_cifar10_architecture4
from tensorflow.examples.tutorials.mnist import input_data
import os
MNIST_DATAPATH = 'simulation/data/mnist/'

mnist = input_data.read_data_sets(MNIST_DATAPATH)
train_data = mnist.train.images
train_labels = mnist.train.labels
test_data = mnist.test.images
test_labels = mnist.test.labels
valid_data = mnist.validation.images
valid_labels = mnist.validation.labels
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# WARNING:tensorflow:From <ipython-input-1-7de1e69742d1>:13: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting simulation/data/mnist/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting simulation/data/mnist/train-labels-idx1-ubyte.gz
# Extracting simulation/data/mnist/t10k-images-idx3-ubyte.gz
# Extracting simulation/data/mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
experiment_name = 'mnist_swap_step_PTLD_dynamic'
tuning_parameter_name = 'swap_attempt_step'
tuning_parameter_vals = list(range(300, 1800, 250))

description = """Tuning of `swap_attempt_step` with constant temp_factor=sqrt(3). 
Difference between steps is 150. Parralel Tempering Langevin Dynamics. 
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments = len(tuning_parameter_vals)
n_simulations = 50
batch_size = 50
n_epochs = 25



temp_factor = np.sqrt(3)
noise_list = [0.01/temp_factor**i for i in range(8)]
noise_list = [1/n for n in noise_list]
print(noise_list)
print(tuning_parameter_vals)

for exp in range(0, n_experiments):
    name = experiment_name + '_' + str(exp)
    print()
    print(name)
    
    sim = Simulator(nn_mnist_architecture, 0.01, noise_list, 'betas',
                   batch_size=batch_size, n_epochs=n_epochs, name=name,
                   n_simulations=n_simulations, swap_attempt_step=tuning_parameter_vals[exp], 
                   temp_factor=temp_factor, tuning_parameter_name=tuning_parameter_name,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
# Out:
# [100.0, 173.20508075688772, 299.99999999999994, 519.6152422706631, 899.9999999999998, 1558.845726811989, 2699.999999999999, 4676.537180435967]
# [300, 550, 800, 1050, 1300, 1550]
#
# mnist_swap_step_PTLD_dynamic_3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-a1806cedc997> in <module>()
#      34     sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
#      35             test_data=test_data, test_labels=test_labels,
# ---> 36             validation_data=valid_data, validation_labels=valid_labels)
#
# ~/project_vlad/deep_tempering/simulation/simulator.py in train_n_times(self, train_func, *args, **kwargs)
#      45                 for i in range(self.n_simulations):
#      46 			self.graph = GraphBuilder(self.architecture, self.learning_rate,
# ---> 47 				self.noise_list, self.name, self.noise_type, self.summary_type, simulation_num=i)
#      48                         train_func(kwargs)
#      49                         gc.collect()
#
# ~/project_vlad/deep_tempering/simulation/simulation_builder/graph_builder.py in __init__(self, architecture, learning_rate, noise_list, name, noise_type, summary_type, simulation_num)
#     127                                 self._cross_entropy_loss_dict, self._zero_one_loss_dict, self._noise_list,
#     128                                 self._noise_plcholders, simulation_num=self._simulation_num,
# --> 129 				summary_type=self._summary_type)
#     130
#     131                         self.variable_initializer = tf.global_variables_initializer()
#
# ~/project_vlad/deep_tempering/simulation/simulation_builder/summary.py in __init__(self, graph, n_replicas, name, loss_dict, zero_one_loss_dict, noise_list, noise_plcholders, simulation_num, summary_type)
#      57 		if (summary_type is None
#      58 			or summary_type == 'replica_summary'):
# ---> 59                         self.create_replica_summary()
#      60 		if (summary_type is None
#      61 			or summary_type == 'ordered_summary'):
#
# ~/project_vlad/deep_tempering/simulation/simulation_builder/summary.py in create_replica_summary(self)
#     125                                         logdir=self.dir.get_test_dir(i),
#     126                                         graph=self.graph,
# --> 127 					filename_suffix=self.dir.get_filename_suffix())
#     128 				self.writer_dict['valid_replica'][i] = tf.summary.FileWriter(
#     129                                         logdir=self.dir.get_validation_dir(i),
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/summary/writer/writer.py in __init__(self, logdir, graph, max_queue, flush_secs, graph_def, filename_suffix, session)
#     365       event_writer = EventFileWriter(logdir, max_queue, flush_secs,
#     366                                      filename_suffix)
# --> 367     super(FileWriter, self).__init__(event_writer, graph, graph_def)
#     368
#     369   def __enter__(self):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/summary/writer/writer.py in __init__(self, event_writer, graph, graph_def)
#      81     if graph is not None or graph_def is not None:
#      82       # Calling it with both graph and graph_def for backward compatibility.
# ---> 83       self.add_graph(graph=graph, graph_def=graph_def)
#      84       # Also export the meta_graph_def in this case.
#      85       # graph may itself be a graph_def due to positional arguments
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/summary/writer/writer.py in add_graph(self, graph, global_step, graph_def)
#     191
#     192       # Serialize the graph with additional info.
# --> 193       true_graph_def = graph.as_graph_def(add_shapes=True)
#     194       self._write_plugin_assets(graph)
#     195     elif (isinstance(graph, graph_pb2.GraphDef) or
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in as_graph_def(self, from_version, add_shapes)
#    3248     """
#    3249     # pylint: enable=line-too-long
# -> 3250     result, _ = self._as_graph_def(from_version, add_shapes)
#    3251     return result
#    3252
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in _as_graph_def(self, from_version, add_shapes)
#    3202             if op.outputs:
#    3203               node.attr["_output_shapes"].list.shape.extend(
# -> 3204                   [output.get_shape().as_proto() for output in op.outputs])
#    3205     else:
#    3206       with self._lock:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in <listcomp>(.0)
#    3202             if op.outputs:
#    3203               node.attr["_output_shapes"].list.shape.extend(
# -> 3204                   [output.get_shape().as_proto() for output in op.outputs])
#    3205     else:
#    3206       with self._lock:
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in get_shape(self)
#     469   def get_shape(self):
#     470     """Alias of Tensor.shape."""
# --> 471     return self.shape
#     472
#     473   def set_shape(self, shape):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/ops.py in shape(self)
#     381
#     382     """
# --> 383     if self._shape_val is None:
#     384       if _USE_C_SHAPES:
#     385         self._shape_val = self._c_api_shape()
#
# KeyboardInterrupt:

# %%
experiment_name = 'mnist_temp_factor_PTLD_dynamic'
tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [np.sqrt(1.1), 
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         4.0]

description = """Tuning of `temp_factor` with constant swap_attempt_step=800. 
Parralel Tempering Langevin Dynamics. 
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 30
batch_size = 50
n_epochs = 25



temp_factor = np.sqrt(2)
noise_list = [0.01/temp_factor**i for i in range(8)]
noise_list = [1/n for n in noise_list]

print(tuning_parameter_vals)
start_time = time()
for exp in range(0, n_experiments):
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [0.01/temp_factor**i for i in range(8)]
    noise_list = [1/n for n in noise_list]
    print(noise_list)
    swap_attempt_step = 800
    sim = Simulator(nn_mnist_architecture, 
                    0.01, noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.0488088481701516, 1.4142135623730951, 1.7320508075688772, 2.0, 2.23606797749979, 2.449489742783178, 2.6457513110645907, 2.8284271247461903, 3.0, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 4.0]
# mnist_temp_factor_PTLD_dynamic_0
# [100.0, 104.88088481701516, 110.0, 115.3689732987167, 121.00000000000004, 126.90587062858836, 133.10000000000005, 139.59645769144726]
# epoch:4, step:4800, 2.5187886,2.4711738,2.731545,2.6484563,2.2616794,2.5112462,2.2498977,2.2155044, accept_ratio:1.0, proba:0.9712138807074837, 0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-183111431aed> in <module>()
#      57     sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
#      58             test_data=test_data, test_labels=test_labels,
# ---> 59             validation_data=valid_data, validation_labels=valid_labels)
#      60     print()
#      61     print('time took:', (time() - start_time)/60.0, 'min')
#
# ~/project_vlad/deep_tempering/simulation/simulator.py in train_n_times(self, train_func, *args, **kwargs)
#      46 			self.graph = GraphBuilder(self.architecture, self.learning_rate,
#      47 				self.noise_list, self.name, self.noise_type, self.summary_type, simulation_num=i)
# ---> 48                         train_func(kwargs)
#      49                         gc.collect()
#      50
#
# ~/project_vlad/deep_tempering/simulation/simulator.py in train_PTLD(self, kwargs)
#      98                                                         feed_dict = g.create_feed_dict(batch['X'], batch['y'])
#      99 							evaluated = sess.run(g.get_train_ops(),
# --> 100 								feed_dict=feed_dict)
#     101                                                         if step % 100 == 0:
#     102                                                                 g.add_summary(evaluated, step=step)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:

# %%
experiment_name = 'mnist_temp_factor_PTLD_static'
tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [np.sqrt(1.1), 
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         4.0]

description = """Tuning of `temp_factor` with constant swap_attempt_step=infty. 
Parralel Tempering Langevin Dynamics. 
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 30
batch_size = 50
n_epochs = 25



temp_factor = np.sqrt(2)
noise_list = [0.01/temp_factor**i for i in range(8)]
noise_list = [1/n for n in noise_list]

print(tuning_parameter_vals)
start_time = time()
for exp in range(0, n_experiments):
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [0.01/temp_factor**i for i in range(8)]
    noise_list = [1/n for n in noise_list]
    print(noise_list)
    swap_attempt_step = 1000000
    sim = Simulator(nn_mnist_architecture, 
                    0.01, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.0488088481701516, 1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 4.0]
# mnist_temp_factor_PTLD_static_0
# [100.0, 104.88088481701516, 110.0, 115.3689732987167, 121.00000000000004, 126.90587062858836, 133.10000000000005, 139.59645769144726]
# epoch:1, step:1400, 3.918464,2.7393851,3.5686526,4.171208,3.0554879,3.2705853,3.0758796,2.9905014, accept_ratio:1.0, proba:0.9857915262107724, 2
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-d168bc2bfa96> in <module>()
#      58     sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
#      59             test_data=test_data, test_labels=test_labels,
# ---> 60             validation_data=valid_data, validation_labels=valid_labels)
#      61     print()
#      62     print('time took:', (time() - start_time)/60.0, 'min')
#
# ~/project_vlad/deep_tempering/simulation/simulator.py in train_n_times(self, train_func, *args, **kwargs)
#      46 			self.graph = GraphBuilder(self.architecture, self.learning_rate,
#      47 				self.noise_list, self.name, self.noise_type, self.summary_type, simulation_num=i)
# ---> 48                         train_func(kwargs)
#      49                         gc.collect()
#      50
#
# ~/project_vlad/deep_tempering/simulation/simulator.py in train_PTLD(self, kwargs)
#      98                                                         feed_dict = g.create_feed_dict(batch['X'], batch['y'])
#      99 							evaluated = sess.run(g.get_train_ops(),
# --> 100 								feed_dict=feed_dict)
#     101                                                         if step % 100 == 0:
#     102                                                                 g.add_summary(evaluated, step=step)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1320   def _do_call(self, fn, *args):
#    1321     try:
# -> 1322       return fn(*args)
#    1323     except errors.OpError as e:
#    1324       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1305       self._extend_graph()
#    1306       return self._call_tf_sessionrun(
# -> 1307           options, feed_dict, fetch_list, target_list, run_metadata)
#    1308
#    1309     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1407       return tf_session.TF_SessionRun_wrapper(
#    1408           self._session, options, feed_dict, fetch_list, target_list,
# -> 1409           run_metadata)
#    1410     else:
#    1411       with errors.raise_exception_on_not_ok_status() as status:
#
# KeyboardInterrupt:
