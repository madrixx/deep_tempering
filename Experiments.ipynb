# %%
import tensorflow as tf
import numpy as np
from time import time
from simulation.simulator import Simulator
from simulation.architectures.mnist_architectures import nn_mnist_architecture
from simulation.architectures.mnist_architectures import cnn_mnist_architecture2
from simulation.architectures.cifar10_architectures import cnn_cifar10_architecture3
from simulation.architectures.cifar10_architectures import cnn_cifar10_architecture4
from tensorflow.examples.tutorials.mnist import input_data
import os
MNIST_DATAPATH = 'simulation/data/mnist/'

mnist = input_data.read_data_sets(MNIST_DATAPATH)
train_data = mnist.train.images
train_labels = mnist.train.labels
test_data = mnist.test.images
test_labels = mnist.test.labels
valid_data = mnist.validation.images
valid_labels = mnist.validation.labels
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# WARNING:tensorflow:From <ipython-input-1-65d167f7f1e1>:13: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting simulation/data/mnist/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting simulation/data/mnist/train-labels-idx1-ubyte.gz
# Extracting simulation/data/mnist/t10k-images-idx3-ubyte.gz
# Extracting simulation/data/mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
experiment_name = 'cnn_mnist_swap_step_PTLD_dynamic'
tuning_parameter_name = 'swap_attempt_step'
tuning_parameter_vals = list(range(300, 1800, 250))

description = """Tuning of `swap_attempt_step` with constant temp_factor=sqrt(3). 
Difference between steps is 150. Parralel Tempering Langevin Dynamics. 
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments = len(tuning_parameter_vals)
n_simulations = 10
batch_size = 50
n_epochs = 25



temp_factor = np.sqrt(3)
noise_list = [0.01/temp_factor**i for i in range(8)]
noise_list = [1/n for n in noise_list]
print(noise_list)1.3185732,0.5519487,0.29798597,0.157029,0.16413233,0.20760933,0.15572442,0.15076347
print(tuning_parameter_vals)

for exp in range(0, n_experimen1ts):
    name = experiment_name + '_' + str(exp)
    print()
    print(name)
    
    sim = Simulator(cnn_mnist_architecture2, 0.001, noise_list, 'betas',
                   batch_size=batch_size, n_epochs=n_epochs, name=name,
                   n_simulations=n_simulations, swap_attempt_step=tuning_parameter_vals[exp], 
                   temp_factor=temp_factor, tuning_parameter_name=tuning_parameter_name,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
# Out:
# [100.0, 173.20508075688772, 299.99999999999994, 519.6152422706631, 899.9999999999998, 1558.845726811989, 2699.999999999999, 4676.537180435967]
# [300, 550, 800, 1050, 1300, 1550]
#
# cnn_mnist_swap_step_PTLD_dynamic_0
# epoch:24, step:27400, 0.62067235,0.24525659,1.2612773,1.4708525,1.2749783,0.7694001,1.2042407,0.5013841, accept_ratio:0.6739130434782604, proba:0.5393089017819409, 0
# cnn_mnist_swap_step_PTLD_dynamic_1
# epoch:24, step:27400, 0.7483551,0.5152117,0.55045426,0.47273847,1.1057531,0.7951892,1.0279983,0.6707225, accept_ratio:0.7199999999999999, proba:0.5655932659049278, -1
# cnn_mnist_swap_step_PTLD_dynamic_2
# epoch:24, step:27400, 0.74599266,0.70187086,0.956926,0.77400243,0.37259766,0.5160814,0.20683151,0.26108298, accept_ratio:0.7999999999999998, proba:0.7573056264357739, 3
# cnn_mnist_swap_step_PTLD_dynamic_3
# epoch:24, step:27400, 0.9333859,1.4649307,1.3826705,0.2683806,0.5553417,0.24273391,0.34992698,0.4866376, accept_ratio:0.8148148148148147, proba:0.737771916431993, 3
# cnn_mnist_swap_step_PTLD_dynamic_4
# epoch:24, step:27400, 1.1538856,1.4247413,0.50805956,0.28329664,0.6417137,0.28452948,0.29140157,0.48740116, accept_ratio:0.7727272727272725, proba:0.911377186027654, 5
# cnn_mnist_swap_step_PTLD_dynamic_5
# epoch:24, step:27400, 0.69004494,0.61803347,1.7110128,1.2183414,0.25973165,0.31896546,0.3366213,0.33548844, accept_ratio:0.8888888888888888, proba:0.920149786557095, 6

# %%
experiment_name = 'cnn_mnist_temp_factor_PTLD_dynamic'
tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [np.sqrt(1.1), 
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         4.0]

description = """Tuning of `temp_factor` with constant swap_attempt_step=800. 
Parralel Tempering Langevin Dynamics. 
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 10
batch_size = 50
n_epochs = 25



temp_factor = np.sqrt(2)
noise_list = [0.01/temp_factor**i for i in range(8)]
noise_list = [1/n for n in noise_list]

print(tuning_parameter_vals)
start_time = time()
for exp in range(0, n_experiments):
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [0.01/temp_factor**i for i in range(8)]
    noise_list = [1/n for n in noise_list]
    print(noise_list)
    swap_attempt_step = 800
    sim = Simulator(cnn_mnist_architecture2, 
                    0.001, noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.0488088481701516, 1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 4.0]
# cnn_mnist_temp_factor_PTLD_dynamic_0
# [100.0, 104.88088481701516, 110.0, 115.3689732987167, 121.00000000000004, 126.90587062858836, 133.10000000000005, 139.59645769144726]
# epoch:24, step:27400, 1.4970274,1.4275477,1.5376836,1.2558324,1.1635758,1.4387225,1.2776579,1.1167138, accept_ratio:1.0, proba:1.0031342009003303, 5
# time took: 48.73984642028809 min
# cnn_mnist_temp_factor_PTLD_dynamic_1
# [100.0, 122.4744871391589, 149.99999999999997, 183.71173070873832, 224.99999999999991, 275.56759606310743, 337.49999999999983, 413.35139409466103]
# epoch:24, step:27400, 0.7161056,1.023848,0.6010776,0.905238,0.6301551,1.0702766,0.9612572,0.83795136, accept_ratio:0.8857142857142855, proba:1.0362657606827896, 6
# time took: 48.769609268506365 min
# cnn_mnist_temp_factor_PTLD_dynamic_2
# [100.0, 141.4213562373095, 200.00000000000003, 282.8427124746191, 400.00000000000006, 565.6854249492383, 800.0000000000005, 1131.3708498984765]
# epoch:24, step:27400, 1.4897106,0.5009301,0.5397095,0.48000655,0.87649834,0.9306127,1.2787424,0.97833514, accept_ratio:0.7428571428571427, proba:0.8420678996118326, -1
# time took: 48.75899147987366 min
# cnn_mnist_temp_factor_PTLD_dynamic_3
# [100.0, 158.11388300841895, 250.00000000000006, 395.2847075210475, 625.0000000000001, 988.2117688026187, 1562.5000000000005, 2470.5294220065475]
# epoch:24, step:27400, 0.38483924,1.0306572,0.70574045,1.3498611,0.2942662,1.0096861,0.48074943,1.6623868, accept_ratio:0.7714285714285714, proba:0.666997919807235, 5
# time took: 48.93093257745107 min
# cnn_mnist_temp_factor_PTLD_dynamic_4
# [100.0, 173.20508075688772, 299.99999999999994, 519.6152422706631, 899.9999999999998, 1558.845726811989, 2699.999999999999, 4676.537180435967]
# epoch:24, step:27400, 0.8217356,0.4583634,0.24601,1.3636137,1.1989889,0.30108505,0.4120376,0.73664695, accept_ratio:0.8857142857142852, proba:1.1272459917620876, 7
# time took: 48.85569282770157 min
# cnn_mnist_temp_factor_PTLD_dynamic_5
# [100.0, 187.08286933869707, 350.0, 654.7900426854397, 1225.0, 2291.765149399039, 4287.499999999999, 8021.178022896635]
# epoch:24, step:27400, 0.9460123,1.3580713,0.49649677,0.326602,0.4168621,0.32070246,0.5681992,0.36994165, accept_ratio:0.6285714285714282, proba:0.7916918823750925, 2
# time took: 48.65265814860662 min
# cnn_mnist_temp_factor_PTLD_dynamic_6
# [100.0, 200.0, 400.0, 800.0, 1600.0, 3200.0, 6400.0, 12800.0]
# epoch:24, step:27400, 0.5025737,0.4608418,0.65820587,1.0956048,1.2722945,0.608517,1.6718875,0.23375896, accept_ratio:0.7428571428571428, proba:0.6732258726065751, 5
# time took: 48.73745683034261 min
# cnn_mnist_temp_factor_PTLD_dynamic_7
# [100.0, 212.13203435596424, 449.9999999999999, 954.5941546018389, 2024.999999999999, 4295.673695708274, 9112.499999999996, 19330.53163068723]
# epoch:24, step:27400, 0.62940294,0.99012625,0.8305078,0.22765812,0.2069851,0.20590532,0.21568608,0.5739318, accept_ratio:0.6571428571428571, proba:0.5515089231853497, 3
# time took: 48.82339835166931 min
# cnn_mnist_temp_factor_PTLD_dynamic_8
# [100.0, 223.606797749979, 500.0000000000001, 1118.0339887498951, 2500.0, 5590.169943749475, 12500.000000000004, 27950.84971874738]
# epoch:24, step:27400, 1.2804679,0.5946897,0.9382387,0.23490795,0.34584445,0.8680909,0.14791352,0.1791322, accept_ratio:0.5714285714285714, proba:0.2431821839277621, -1
# time took: 48.731322181224826 min
# cnn_mnist_temp_factor_PTLD_dynamic_9
# [100.0, 234.52078799117146, 550.0, 1289.8643339514433, 3025.0000000000005, 7094.253836732939, 16637.500000000004, 39018.39610203117]
# epoch:24, step:27400, 0.5548369,0.20447986,1.424776,1.2865895,0.3697499,0.1793474,0.5910662,0.19714408, accept_ratio:0.6285714285714283, proba:0.9725154133196018, 6
# time took: 48.84306832949321 min
# cnn_mnist_temp_factor_PTLD_dynamic_10
# [100.0, 244.9489742783178, 599.9999999999999, 1469.6938456699065, 3599.9999999999986, 8818.163074019438, 21599.99999999999, 52908.97844411661]
# epoch:24, step:27400, 0.58133817,0.37898555,1.5296321,0.8455367,0.1454272,0.16034897,0.16185333,0.17968103, accept_ratio:0.4, proba:0.9165676526847937, -1
# time took: 48.780503745873766 min
# cnn_mnist_temp_factor_PTLD_dynamic_11
# [100.0, 254.9509756796392, 649.9999999999999, 1657.1813419176547, 4224.999999999998, 10771.678722464754, 27462.49999999999, 70015.91169602089]
# epoch:24, step:27400, 1.4949588,0.18160452,0.27441844,0.26492736,0.2880947,0.5906237,0.1727921,0.28088573, accept_ratio:0.5142857142857142, proba:0.4155381203682804, 1
# time took: 48.78298253218333 min
# cnn_mnist_temp_factor_PTLD_dynamic_12
# [100.0, 264.5751311064591, 700.0000000000001, 1852.0259177452135, 4900.000000000001, 12964.181424216496, 34300.00000000001, 90749.26996951549]
# epoch:24, step:27400, 0.77533126,0.54424816,1.0076313,0.1982316,0.17008922,0.147343,0.20514727,0.27423567, accept_ratio:0.42857142857142855, proba:0.43017927179441573, 0
# time took: 48.89191382328669 min
# cnn_mnist_temp_factor_PTLD_dynamic_13
# [100.0, 273.8612787525831, 750.0, 2053.959590644373, 5625.0, 15404.696929832797, 42187.5, 115535.22697374597]
# epoch:24, step:27400, 0.5105892,2.3051622,0.28695428,1.2291279,1.2233008,0.16587566,0.16908483,0.1767902, accept_ratio:0.5142857142857142, proba:0.8239025355559456, 5
# time took: 48.91271818876267 min
# cnn_mnist_temp_factor_PTLD_dynamic_14
# [100.0, 400.0, 1600.0, 6400.0, 25600.0, 102400.0, 409600.0, 1638400.0]
# epoch:24, step:27400, 1.3185732,0.5519487,0.29798597,0.157029,0.16413233,0.20760933,0.15572442,0.15076347, accept_ratio:0.2857142857142857, proba:0.4506313945829293, -1
# time took: 48.7797957777977 min

# %%
experiment_name = 'cnn_mnist_temp_factor_PTLD_static'
tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [np.sqrt(1.1), 
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         4.0]

description = """Tuning of `temp_factor` with constant swap_attempt_step=infty. 
Parralel Tempering Langevin Dynamics. 
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 10
batch_size = 50
n_epochs = 25



temp_factor = np.sqrt(2)
noise_list = [0.01/temp_factor**i for i in range(8)]
noise_list = [1/n for n in noise_list]

print(tuning_parameter_vals)
start_time = time()
for exp in range(0, n_experiments):
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [0.01/temp_factor**i for i in range(8)]
    noise_list = [1/n for n in noise_list]
    print(noise_list)
    swap_attempt_step = 1000000
    sim = Simulator(cnn_mnist_architecture2, 
                    0.001, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.0488088481701516, 1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 4.0]
# cnn_mnist_temp_factor_PTLD_static_0
# [100.0, 104.88088481701516, 110.0, 115.3689732987167, 121.00000000000004, 126.90587062858836, 133.10000000000005, 139.59645769144726]
# epoch:24, step:27400, 2.0063581,1.3620416,1.3432727,1.1408081,1.2210711,1.521664,0.939879,1.2109, accept_ratio:1.0, proba:0.9947883293040998, 2
# time took: 47.53801750342051 min
# cnn_mnist_temp_factor_PTLD_static_1
# [100.0, 122.4744871391589, 149.99999999999997, 183.71173070873832, 224.99999999999991, 275.56759606310743, 337.49999999999983, 413.35139409466103]
# epoch:24, step:27400, 2.0252926,1.0262911,0.99226534,0.8693834,0.805205,0.7487418,0.5863135,0.7083365, accept_ratio:1.0, proba:0.9112422595231061, 7
# time took: 47.64033611615499 min
# cnn_mnist_temp_factor_PTLD_static_2
# [100.0, 141.4213562373095, 200.00000000000003, 282.8427124746191, 400.00000000000006, 565.6854249492383, 800.0000000000005, 1131.3708498984765]
# epoch:24, step:27400, 1.7813222,0.89021975,1.0415146,0.6562477,0.67494905,0.53923684,0.4359619,0.3760012, accept_ratio:1.0, proba:0.7593088289038663, 2
# time took: 47.73490539391835 min
# cnn_mnist_temp_factor_PTLD_static_3
# [100.0, 158.11388300841895, 250.00000000000006, 395.2847075210475, 625.0000000000001, 988.2117688026187, 1562.5000000000005, 2470.5294220065475]
# epoch:24, step:27400, 2.1192408,0.89536583,0.76074696,0.62755567,0.55066204,0.37948257,0.26892892,0.3143071, accept_ratio:1.0, proba:0.6150066410310835, 7
# time took: 47.86410219271978 min
# cnn_mnist_temp_factor_PTLD_static_4
# [100.0, 173.20508075688772, 299.99999999999994, 519.6152422706631, 899.9999999999998, 1558.845726811989, 2699.999999999999, 4676.537180435967]
# epoch:24, step:27400, 1.4070672,0.8939159,0.7466958,0.6015175,0.39496815,0.3191298,0.23494199,0.2546605, accept_ratio:1.0, proba:0.49710738801793203, 7
# time took: 48.74034107526143 min
# cnn_mnist_temp_factor_PTLD_static_5
# [100.0, 187.08286933869707, 350.0, 654.7900426854397, 1225.0, 2291.765149399039, 4287.499999999999, 8021.178022896635]
# epoch:24, step:27400, 1.216675,0.89161825,0.64022326,0.4661828,0.36149758,0.2736889,0.23325257,0.194021, accept_ratio:0.0, proba:0.39283117493879405, -1
# time took: 47.44164523681005 min
# cnn_mnist_temp_factor_PTLD_static_6
# [100.0, 200.0, 400.0, 800.0, 1600.0, 3200.0, 6400.0, 12800.0]
# epoch:24, step:27400, 1.2847401,0.75829905,0.6096402,0.48686144,0.32464796,0.26164088,0.20694868,0.18987344, accept_ratio:0.0, proba:0.3157021702893381, -1
# time took: 48.3067587574323 min
# cnn_mnist_temp_factor_PTLD_static_7
# [100.0, 212.13203435596424, 449.9999999999999, 954.5941546018389, 2024.999999999999, 4295.673695708274, 9112.499999999996, 19330.53163068723]
# epoch:24, step:27400, 1.9817617,0.9356252,0.58901626,0.3884814,0.26359463,0.2226467,0.18548886,0.18193409, accept_ratio:0.0, proba:0.2580935922685927, -1
# time took: 47.94552359183629 min
# cnn_mnist_temp_factor_PTLD_static_8
# [100.0, 223.606797749979, 500.0000000000001, 1118.0339887498951, 2500.0, 5590.169943749475, 12500.000000000004, 27950.84971874738]
# epoch:24, step:27400, 1.9062895,0.87676126,0.35481718,0.48717675,0.25928316,0.21808589,0.17188455,0.16693647, accept_ratio:1.0, proba:0.2073054981065708, 3
# time took: 47.790677626927696 min
# cnn_mnist_temp_factor_PTLD_static_9
# [100.0, 234.52078799117146, 550.0, 1289.8643339514433, 3025.0000000000005, 7094.253836732939, 16637.500000000004, 39018.39610203117]
# epoch:24, step:27400, 2.3015013,0.8926756,0.5264076,0.34337103,0.25753972,0.21185967,0.17813294,0.1618937, accept_ratio:0.0, proba:0.16856927823573842, -1
# time took: 47.456306334336595 min
# cnn_mnist_temp_factor_PTLD_static_10
# [100.0, 244.9489742783178, 599.9999999999999, 1469.6938456699065, 3599.9999999999986, 8818.163074019438, 21599.99999999999, 52908.97844411661]
# epoch:24, step:27400, 2.1048007,0.8422576,0.56857073,0.30380565,0.2198791,0.18359725,0.1747521,0.1521707, accept_ratio:0.0, proba:0.13820176947705679, -1
# time took: 47.6792223294576 min
# cnn_mnist_temp_factor_PTLD_static_11
# [100.0, 254.9509756796392, 649.9999999999999, 1657.1813419176547, 4224.999999999998, 10771.678722464754, 27462.49999999999, 70015.91169602089]
# epoch:24, step:27400, 1.4461645,0.7919475,0.46843895,0.33066377,0.22518925,0.17496002,0.18020022,0.17155264, accept_ratio:0.0, proba:0.11318707661993434, -1
# time took: 47.73011742432912 min
# cnn_mnist_temp_factor_PTLD_static_12
# [100.0, 264.5751311064591, 700.0000000000001, 1852.0259177452135, 4900.000000000001, 12964.181424216496, 34300.00000000001, 90749.26996951549]
# epoch:24, step:27400, 1.7760023,0.8117598,0.47684816,0.2941012,0.21937959,0.1730518,0.15573277,0.16087082, accept_ratio:0.0, proba:0.0943427193990456, -1
# time took: 47.89186607996623 min
# cnn_mnist_temp_factor_PTLD_static_13
# [100.0, 273.8612787525831, 750.0, 2053.959590644373, 5625.0, 15404.696929832797, 42187.5, 115535.22697374597]
# epoch:24, step:27400, 2.0251272,0.7902405,0.49651065,0.27073425,0.21992439,0.17558746,0.15407194,0.15598974, accept_ratio:0.0, proba:0.07774778595768715, -1
# time took: 47.991406488418576 min
# cnn_mnist_temp_factor_PTLD_static_14
# [100.0, 400.0, 1600.0, 6400.0, 25600.0, 102400.0, 409600.0, 1638400.0]
# epoch:24, step:27400, 1.2795203,0.66772527,0.33501384,0.21023609,0.15551789,0.1718148,0.15127349,0.1571076, accept_ratio:0.0, proba:0.0054889177019426545, -1
# time took: 48.08162431319555 min

# %%
experiment_name = 'todelete'
tuning_parameter_name = 'swap_attempt_step'
tuning_parameter_vals = list(range(300, 1800, 250))

description = """Tuning of `swap_attempt_step` with constant temp_factor=sqrt(3). 
Difference between steps is 150. Parralel Tempering Langevin Dynamics. 
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments = len(tuning_parameter_vals)
n_simulations = 3
batch_size = 50
n_epochs = 1

n_experiments = len(tuning_parameter_vals)

temp_factor = np.sqrt(3)
noise_list = [0.01/temp_factor**i for i in range(3)]
noise_list = [1/n for n in noise_list]
print(noise_list)
print(tuning_parameter_vals)

for exp in range(0, n_experiments):
    name = experiment_name + '_' + str(exp)
    print()
    print(name)
    
    sim = Simulator(nn_mnist_architecture, 0.01, noise_list, 'betas',
                   batch_size=batch_size, n_epochs=n_epochs, name=name,
                   n_simulations=n_simulations, swap_attempt_step=tuning_parameter_vals[exp], 
                   temp_factor=temp_factor, tuning_parameter_name=tuning_parameter_name,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
# Out:
# [100.0, 173.20508075688772, 299.99999999999994]
# [300, 550, 800, 1050, 1300, 1550]
#
# todelete_0
# epoch:0, step:1000, 3.9135187,2.146288,1.3291053, accept_ratio:0.0, proba:0.11710323245827907, -1               		           	3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_0/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_0/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_0/2/summary.pickle
# 3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_0/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_0/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_0/2/summary.pickle
# 3 simulations
#
# todelete_1
# epoch:0, step:1000, 3.844666,2.2988038,1.4824622, accept_ratio:0.0, proba:0.41354673389542573, -1               	3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_1/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_1/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_1/2/summary.pickle
# 3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_1/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_1/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_1/2/summary.pickle
# 3 simulations
#
# todelete_2
# epoch:0, step:1000, 4.033393,2.1692703,1.5532268, accept_ratio:0.0, proba:0.428699416667924, -1               	 	3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_2/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_2/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_2/2/summary.pickle
# 3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_2/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_2/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_2/2/summary.pickle
# 3 simulations
#
# todelete_3
# Exception ignored in: <bound method ScopedTFGraph.__del__ of <tensorflow.python.framework.c_api_util.ScopedTFGraph object at 0x7f17898bf588>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/framework/c_api_util.py", line 52, in __del__
#     c_api.TF_DeleteGraph(self.graph)
# KeyboardInterrupt
# epoch:0, step:1000, 3.684963,2.412757,1.3662479, accept_ratio:0.0, proba:0.4392091966907024, -1               			3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_3/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_3/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_3/2/summary.pickle
# 3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_3/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_3/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_3/2/summary.pickle
# 3 simulations
#
# todelete_4
# epoch:0, step:1000, 4.423308,2.3260128,1.4272726, accept_ratio:0.0, proba:0.46177436392414883, -1               	3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_4/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_4/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_4/2/summary.pickle
# 3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_4/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_4/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_4/2/summary.pickle
# 3 simulations
#
# todelete_5
# epoch:0, step:1000, 2.2330704,4.104959,1.5227965, accept_ratio:1.0, proba:0.46140593999894386, 1               	3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_5/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_5/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_5/2/summary.pickle
# 3 simulations
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_5/0/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_5/1/summary.pickle
# uncompressed /home/deep09/project_vlad/deep_tempering/simulation/summaries/compressed/todelete_5/2/summary.pickle
# 3 simulations

# %%
mse.
