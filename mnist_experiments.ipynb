# %%
import tensorflow as tf
import numpy as np
from time import time
from simulation.simulator import Simulator
from simulation.architectures.mnist_architectures import nn_mnist_architecture
from simulation.architectures.mnist_architectures import cnn_mnist_architecture2
from simulation.architectures.cifar10_architectures import cnn_cifar10_architecture3
from simulation.architectures.cifar10_architectures import cnn_cifar10_architecture4
from tensorflow.examples.tutorials.mnist import input_data
import os
MNIST_DATAPATH = 'simulation/data/mnist/'

mnist = input_data.read_data_sets(MNIST_DATAPATH)
train_data = mnist.train.images
train_labels = mnist.train.labels
test_data = mnist.test.images
test_labels = mnist.test.labels
valid_data = mnist.validation.images
valid_labels = mnist.validation.labels
# Out:
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# /usr/lib/python3.5/importlib/_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# WARNING:tensorflow:From <ipython-input-1-65d167f7f1e1>:13: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting simulation/data/mnist/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting simulation/data/mnist/train-labels-idx1-ubyte.gz
# Extracting simulation/data/mnist/t10k-images-idx3-ubyte.gz
# Extracting simulation/data/mnist/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
"""EXPERIMENT1







n_replicas = 6
starts at beta = 50

"""
# Out:
# 'EXPERIMENT1\n\n\n\n\n\n\n\nn_replicas = 6\nstarts at beta = 50\n\n'

# %% [markdown]
# """NN architecture """
#
# experiment_name = 'nn_mnist_tempfactor_PTLD_dynamic_6_energy'
#
# """Experiment name:
#     <arhictecture>_<dataset>_<tuning parameter>_<optimizer>_<dynamic=swaps occure/static=swaps don't occur>_
#     <n_replicas>_<surface view>"""
#
#
# tuning_parameter_name = 'temp_factor'
# tuning_parameter_vals = [
#                          np.sqrt(1.5),
#                          np.sqrt(2),
#                          np.sqrt(2.5),
#                          np.sqrt(3),
#                          np.sqrt(3.5),
#                          np.sqrt(4),
#                          np.sqrt(4.5),
#                          np.sqrt(5),
#                          np.sqrt(5.5),
#                          np.sqrt(6),
#                          np.sqrt(6.5),
#                          np.sqrt(7),
#                          np.sqrt(7.5),
#                          np.sqrt(8),
#                          np.sqrt(8.5),
#                          np.sqrt(9),
#                          np.sqrt(9.5),
#                          np.sqrt(10),
#                          np.sqrt(11),
#                          np.sqrt(12),
#                          np.sqrt(13),
#                          np.sqrt(14),
#                          np.sqrt(15)]
#
# description = """Tuning of `temp_factor` with constant swap_attempt_step=600.
# Parralel Tempering Langevin Dynamics. 6 replicas
# Tuning parameters values are """ + str(tuning_parameter_vals)
# n_experiments= len(tuning_parameter_vals)
# n_simulations = 15
# batch_size = 50
# n_epochs = 25
# swap_attempt_step = 600
# n_replicas = 6
# surface_view = 'energy'
#
#
# print(tuning_parameter_vals)
# start_time = time()
# for exp in range(n_experiments):
#     print('experiment:', exp+1, '/', n_experiments)
#     name = experiment_name + '_' + str(exp)
#
#     print(name)
#     temp_factor = tuning_parameter_vals[exp]
#     noise_list = [50*temp_factor**i for i in range(n_replicas)]
#
#     print(noise_list)
#
#     sim = Simulator(nn_mnist_architecture,
#                     0.01,
#                     noise_list,
#                     'betas',
#                     batch_size=batch_size,
#                     n_epochs=n_epochs,
#                     name=name,
#                     n_simulations=n_simulations,
#                     swap_attempt_step=swap_attempt_step,
#                     temp_factor=temp_factor,
#                     tuning_parameter_name=tuning_parameter_name,
#                     surface_view=surface_view,
#                     description=description)
#
#
#     sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
#             test_data=test_data, test_labels=test_labels,
#             validation_data=valid_data, validation_labels=valid_labels)
#     print()
#     print('time took:', (time() - start_time)/60.0, 'min')
#     start_time = time()

# %% [markdown]
# """CNN architecture"""
# experiment_name = 'cnn_mnist_tempfactor_PTLD_dynamic_6_energy'
#
# tuning_parameter_name = 'temp_factor'
# tuning_parameter_vals = [
#                          np.sqrt(1.5),
#                          np.sqrt(2),
#                          np.sqrt(2.5),
#                          np.sqrt(3),
#                          np.sqrt(3.5),
#                          np.sqrt(4),
#                          np.sqrt(4.5),
#                          np.sqrt(5),
#                          np.sqrt(5.5),
#                          np.sqrt(6),
#                          np.sqrt(6.5),
#                          np.sqrt(7),
#                          np.sqrt(7.5),
#                          np.sqrt(8),
#                          np.sqrt(8.5),
#                          np.sqrt(9),
#                          np.sqrt(9.5),
#                          np.sqrt(10),
#                          np.sqrt(11),
#                          np.sqrt(12),
#                          np.sqrt(13),
#                          np.sqrt(14),
#                          np.sqrt(15)]
#
# description = """Tuning of `temp_factor` with constant swap_attempt_step=600.
# Parralel Tempering Langevin Dynamics. 6 replicas
# Tuning parameters values are """ + str(tuning_parameter_vals)
# n_experiments= len(tuning_parameter_vals)
# n_simulations = 15
# batch_size = 50
# n_epochs = 25
# swap_attempt_step = 600
# n_replicas = 6
# surface_view='energy'
#
#
#
#
# print(tuning_parameter_vals)
# start_time = time()
# for exp in range(n_experiments):
#     print('experiment:', exp+1, '/', n_experiments)
#     name = experiment_name + '_' + str(exp)
#
#     print(name)
#     temp_factor = tuning_parameter_vals[exp]
#     noise_list = [50*temp_factor**i for i in range(n_replicas)]
#
#     print(noise_list)
#
#     sim = Simulator(cnn_mnist_architecture2,
#                     0.001,
#                     noise_list,
#                     'betas',
#                     batch_size=batch_size,
#                     n_epochs=n_epochs,
#                     name=name,
#                     n_simulations=n_simulations,
#                     swap_attempt_step=swap_attempt_step,
#                     temp_factor=temp_factor,
#                     tuning_parameter_name=tuning_parameter_name,
#                     surface_view=surface_view,
#                     description=description)
#
#
#     sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
#             test_data=test_data, test_labels=test_labels,
#             validation_data=valid_data, validation_labels=valid_labels)
#     print()
#     print('time took:', (time() - start_time)/60.0, 'min')
#     start_time = time()

# %% [markdown]
# """NN architecture"""
# """Experiment name:
#     <arhictecture>_<dataset>_<tuning parameter>_<optimizer>_<dynamic=swaps occure/static=swaps don't occur>_
#     <nrepl#=n_replicas>_<surface view>"""
#
# experiment_name = 'nn_mnist_tempfactor_PTLD_dynamic_6_information'
# tuning_parameter_name = 'temp_factor'
# tuning_parameter_vals = [
#                          np.sqrt(1.5),
#                          np.sqrt(2),
#                          np.sqrt(2.5),
#                          np.sqrt(3),
#                          np.sqrt(3.5),
#                          np.sqrt(4),
#                          np.sqrt(4.5),
#                          np.sqrt(5),
#                          np.sqrt(5.5),
#                          np.sqrt(6),
#                          np.sqrt(6.5),
#                          np.sqrt(7),
#                          np.sqrt(7.5),
#                          np.sqrt(8),
#                          np.sqrt(8.5),
#                          np.sqrt(9),
#                          np.sqrt(9.5),
#                          np.sqrt(10),
#                          np.sqrt(11),
#                          np.sqrt(12),
#                          np.sqrt(13),
#                          np.sqrt(14),
#                          np.sqrt(15)]
#
# description = """Tuning of `temp_factor` with constant swap_attempt_step=600.
# Parralel Tempering Langevin Dynamics. 6 replicas
# Tuning parameters values are """ + str(tuning_parameter_vals)
# n_experiments= len(tuning_parameter_vals)
# n_simulations = 15
# batch_size = 50
# n_epochs = 25
# swap_attempt_step = 600
# n_replicas = 6
# surface_view = 'information'
#
#
#
# print(tuning_parameter_vals)
# start_time = time()
# for exp in range(n_experiments):
#     print('experiment:', exp+1, '/', n_experiments)
#     name = experiment_name + '_' + str(exp)
#
#     print(name)
#     temp_factor = tuning_parameter_vals[exp]
#     noise_list = [50*temp_factor**i for i in range(n_replicas)]
#
#     print(noise_list)
#
#     sim = Simulator(nn_mnist_architecture,
#                     0.01,
#                     noise_list,
#                     'betas',
#                     batch_size=batch_size,
#                     n_epochs=n_epochs,
#                     name=name,
#                     n_simulations=n_simulations,
#                     swap_attempt_step=swap_attempt_step,
#                     temp_factor=temp_factor,
#                     tuning_parameter_name=tuning_parameter_name,
#                     surface_view=surface_view,
#                     description=description)
#
#
#     sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
#             test_data=test_data, test_labels=test_labels,
#             validation_data=valid_data, validation_labels=valid_labels)
#     print()
#     print('time took:', (time() - start_time)/60.0, 'min')
#     start_time = time()

# %% [markdown]
# """CNN architecture"""
# experiment_name = 'cnn_mnist_tempfactor_PTLD_dynamic_6_information'
#
# tuning_parameter_name = 'temp_factor'
# tuning_parameter_vals = [
#                          np.sqrt(1.5),
#                          np.sqrt(2),
#                          np.sqrt(2.5),
#                          np.sqrt(3),
#                          np.sqrt(3.5),
#                          np.sqrt(4),
#                          np.sqrt(4.5),
#                          np.sqrt(5),
#                          np.sqrt(5.5),
#                          np.sqrt(6),
#                          np.sqrt(6.5),
#                          np.sqrt(7),
#                          np.sqrt(7.5),
#                          np.sqrt(8),
#                          np.sqrt(8.5),
#                          np.sqrt(9),
#                          np.sqrt(9.5),
#                          np.sqrt(10),
#                          np.sqrt(11),
#                          np.sqrt(12),
#                          np.sqrt(13),
#                          np.sqrt(14),
#                          np.sqrt(15)]
#
# description = """Tuning of `temp_factor` with constant swap_attempt_step=600.
# Parralel Tempering Langevin Dynamics. 6 replicas
# Tuning parameters values are """ + str(tuning_parameter_vals)
# n_experiments= len(tuning_parameter_vals)
# n_simulations = 15
# batch_size = 50
# n_epochs = 25
# swap_attempt_step = 600
# n_replicas = 6
# surface_view='information'
#
#
#
#
# print(tuning_parameter_vals)
# start_time = time()
# for exp in range(n_experiments):
#     print('experiment:', exp+1, '/', n_experiments)
#     name = experiment_name + '_' + str(exp)
#
#     print(name)
#     temp_factor = tuning_parameter_vals[exp]
#     noise_list = [50*temp_factor**i for i in range(n_replicas)]
#
#     print(noise_list)
#
#     sim = Simulator(cnn_mnist_architecture2,
#                     0.001,
#                     noise_list,
#                     'betas',
#                     batch_size=batch_size,
#                     n_epochs=n_epochs,
#                     name=name,
#                     n_simulations=n_simulations,
#                     swap_attempt_step=swap_attempt_step,
#                     temp_factor=temp_factor,
#                     tuning_parameter_name=tuning_parameter_name,
#                     surface_view=surface_view,
#                     description=description)
#
#
#     sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
#             test_data=test_data, test_labels=test_labels,
#             validation_data=valid_data, validation_labels=valid_labels)
#     print()
#     print('time took:', (time() - start_time)/60.0, 'min')
#     start_time = time()

# %%
"""EXPERIMENT 2




n_replicas = 4
starts at beta = 50
















"""
n_replicas = 4
beta_0 = 50

# %%
"""NN architecture """

experiment_name = 'nn_mnist_tempfactor_PTLD_dynamic
/ 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_12
# [50.0, 136.93063937629154, 375.0, 1026.9797953221864]
# epoch:24, step:27500, 3.6493359,3.1491342,0.8342805,1.5575081, accept_ratio:0.04347826086956522, proba:1.2669267976732881e-89
# time took: 16.070019443829853 min
# experiment: 14 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_13
# [50.0, 141.4213562373095, 400.0000000000001, 1131.3708498984763]
# epoch:24, step:27500, 3.6964164,2.4015644,0.76981133,1.3737925, accept_ratio:0.02173913043478261, proba:5.862062989884984e-20
# time took: 16.07819210290909 min
# experiment: 15 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_14
# [50.0, 145.77379737113253, 425.0, 1239.0772776546266]
# epoch:24, step:27500, 2.7859704,1.4225626,2.6063304,0.71824455, accept_ratio:0.02173913043478261, proba:2.981550687697254e-139
# time took: 16.08996724287669 min
# experiment: 16 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_15
# [50.0, 150.0, 450.0, 1350.0]
# epoch:24, step:27500, 3.5388632,2.529078,1.5975715,0.6225331, accept_ratio:0.0, proba:0.0         15256747e-46          1e-42
# time took: 16.111751766999564 min
# experiment: 17 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_16
# [50.0, 154.1103500742244, 474.9999999999999, 1464.0483257051317]
# epoch:24, step:27500, 2.8645883,1.2987633,2.3832934,0.6434522, accept_ratio:0.02173913043478261, proba:2.45239405351647e-161
# time took: 16.132747705777486 min
# experiment: 18 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_17
# [50.0, 158.11388300841898, 500.0000000000001, 1581.13883008419]
# epoch:24, step:27500, 3.0146594,2.386729,1.2347399,0.56606, accept_ratio:0.0, proba:7.331009863396037e-25               -31
# time took: 16.164978369077048 min
# experiment: 19 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_18
# [50.0, 165.83123951777, 550.0, 1824.14363469547]
# epoch:24, step:27500, 2.564333,2.7266076,1.2006656,0.55372053, accept_ratio:0.02173913043478261, proba:2.700195815554912e-14
# time took: 16.18198616504669 min
# experiment: 20 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_19
# [50.0, 173.20508075688772, 599.9999999999999, 2078.4609690826524]
# epoch:24, step:27500, 3.349068,2.4361546,1.0559978,0.51641196, accept_ratio:0.0, proba:0.0004504152754864613               -236
# time took: 16.196931405862173 min
# experiment: 21 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_20
# [50.0, 180.27756377319946, 649.9999999999999, 2343.6083290515926]
# epoch:24, step:27500, 4.1724367,1.0851467,2.5289068,0.4638539, accept_ratio:0.02173913043478261, proba:0.0           5508e-291
# time took: 16.223100697994234 min
# experiment: 22 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_21
# [50.0, 187.08286933869707, 700.0, 2619.160170741759]
# epoch:24, step:27500, 2.4290957,3.3032484,0.92130196,0.45356533, accept_ratio:0.02173913043478261, proba:0.0         87214e-22
# time took: 16.208414483070374 min
# experiment: 23 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_50_22
# [50.0, 193.64916731037084, 750.0000000000001, 2904.737509655563]
# epoch:24, step:27500, 2.9131937,0.9730904,2.3726072,0.42791137, accept_ratio:0.02173913043478261, proba:2.653603843799068e-38
# /home/deep09/project_vlad/deep_tempering/simulation/simulation_builder/graph_builder.py:306: RuntimeWarning: overflow encountered in exp
#   accept_proba = np.exp((l1-l2)*(beta[i] - beta[j]))
# epoch:24, step:27500, 3.2594483,1.0215381,2.0844884,0.41084647, accept_ratio:0.02173913043478261, proba:0.0           65e-274
# time took: 16.228613313039144 min

# %%
"""CNN architecture"""

"""Experiment name:
    <arhictecture>_<dataset>_<tuning parameter>_<optimizer>_<dynamic=swaps occure/static=swaps don't occur>_
    <n_replicas>_<surface view>_<starting_beta_>"""

experiment_name = 'cnn_mnist_tempfactor_PTLD_dynamic_4_energy_50'

tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         np.sqrt(8),
                         np.sqrt(8.5),
                         np.sqrt(9),
                         np.sqrt(9.5),
                         np.sqrt(10),
                         np.sqrt(11),
                         np.sqrt(12),
                         np.sqrt(13),
                         np.sqrt(14),
                         np.sqrt(15)]

description = """Tuning of `temp_factor` with constant swap_attempt_step=600. 
Parralel Tempering Langevin Dynamics. 4 replicas
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 15
batch_size = 50
n_epochs = 25
swap_attempt_step = 600
surface_view='energy'




print(tuning_parameter_vals)
start_time = time()
for exp in range(n_experiments):
    print('experiment:', exp+1, '/', n_experiments)
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [beta_0*temp_factor**i for i in range(n_replicas)]

    print(noise_list)
    
    sim = Simulator(cnn_mnist_architecture2, 
                    0.001, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    surface_view=surface_view,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 2.8284271247461903, 2.9154759474226504, 3.0, 3.082207001484488, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 3.872983346207417]
# experiment: 1 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_50
/ 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_250_16
# [50.0, 154.1103500742244, 474.9999999999999, 1464.0483257051317]
# epoch:24, step:27500, 3.4248064,1.3297864,2.347323,0.6447498, accept_ratio:0.02173913043478261, proba:1.8947458924864934e-289
# time took: 17.030211770534514 min
# experiment: 18 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_250_17
# [50.0, 158.11388300841898, 500.0000000000001, 1581.13883008419]
# epoch:24, step:27500, 3.1871235,2.4822228,1.2942184,0.61972517, accept_ratio:0.0, proba:0.0         28853e-67           e-141
# time took: 17.03169127702713 min
# experiment: 19 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_250_18
# [50.0, 165.83123951777, 550.0, 1824.14363469547]
# epoch:24, step:27500, 3.4966593,2.582809,1.1669607,0.56740147, accept_ratio:0.0, proba:3.0546914755968204e-158         3e-228
# time took: 17.047914465268452 min
# experiment: 20 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_250_19
# [50.0, 173.20508075688772, 599.9999999999999, 2078.4609690826524]
# epoch:24, step:27500, 2.9293458,3.3355696,1.1659036,0.5616856, accept_ratio:0.02173913043478261, proba:8.829404566350046e-42
# time took: 17.0496182401975 min
# experiment: 21 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_250_20
# [50.0, 180.27756377319946, 649.9999999999999, 2343.6083290515926]
# epoch:24, step:27500, 2.3014958,3.875035,1.1295723,0.43626654, accept_ratio:0.08695652173913045, proba:0.0         71.867
# time took: 17.056946802139283 min
# experiment: 22 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_250_21
# [50.0, 187.08286933869707, 700.0, 2619.160170741759]
# epoch:24, step:27500, 3.1815732,2.3344696,0.9399261,0.46391168, accept_ratio:0.0, proba:9.10495324095e-311             81e-260
# time took: 17.050025367736815 min
# experiment: 23 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_energy_250_22
# [50.0, 193.64916731037084, 750.0000000000001, 2904.737509655563]
# epoch:24, step:27500, 3.7649305,2.2983015,0.93496877,0.43455508, accept_ratio:0.0, proba:1.6699303789406792e-301         -67
# time took: 17.058744819959006 min

# %%
"""CNN architecture"""

"""Experiment name:
    <arhictecture>_<dataset>_<tuning parameter>_<optimizer>_<dynamic=swaps occure/static=swaps don't occur>_
    <n_replicas>_<surface view>_<starting_beta_>"""

experiment_name = 'cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250'

tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         np.sqrt(8),
                         np.sqrt(8.5),
                         np.sqrt(9),
                         np.sqrt(9.5),
                         np.sqrt(10),
                         np.sqrt(11),
                         np.sqrt(12),
                         np.sqrt(13),
                         np.sqrt(14),
                         np.sqrt(15)]

description = """Tuning of `temp_factor` with constant swap_attempt_step=600. 
Parralel Tempering Langevin Dynamics. 4 replicas
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 15
batch_size = 50
n_epochs = 25
swap_attempt_step = 600
surface_view='energy'




print(tuning_parameter_vals)
start_time = time()
for exp in range(n_experiments):
    print('experiment:', exp+1, '/', n_experiments)
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [beta_0*temp_factor**i for i in range(n_replicas)]

    print(noise_list)
    
    sim = Simulator(cnn_mnist_architecture2, 
                    0.001, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    surface_view=surface_view,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 2.8284271247461903, 2.9154759474226504, 3.0, 3.082207001484488, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 3.872983346207417]
# experiment: 1 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_0
# [250.0, 306.18621784789724, 374.99999999999994, 459.2793267718458]
# epoch:24, step:27500, 0.6758011,0.7191671,0.78317475,0.63149744, accept_ratio:0.32608695652173914, proba:0.024271065514383915
# time took: 35.509798792998 min
# experiment: 2 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_1
# [250.0, 353.5533905932738, 500.0000000000001, 707.1067811865477]
# epoch:24, step:27500, 0.84745324,0.5340999,0.7036537,0.64195734, accept_ratio:0.3695652173913042, proba:5.483343367716258e-17
# time took: 35.31620649496714 min
# experiment: 3 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_2
# [250.0, 395.28470752104744, 625.0000000000001, 988.2117688026187]
# epoch:24, step:27500, 0.8374498,0.41643712,0.42078915,0.48676953, accept_ratio:0.2391304347826087, proba:1.6263909275733873e-05
# time took: 35.4141619404157 min
# experiment: 4 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_3
# [250.0, 433.0127018922193, 749.9999999999999, 1299.0381056766578]
# epoch:24, step:27500, 0.5314371,0.5355459,0.5569305,0.3337761, accept_ratio:0.4130434782608696, proba:2.8892281853440334e-46
# time took: 35.21840960979462 min
# experiment: 5 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_4
# [250.0, 467.70717334674265, 875.0, 1636.9751067135994]
# epoch:24, step:27500, 0.82919323,0.42954415,0.37186027,0.4083707, accept_ratio:0.28260869565217395, proba:4.698480197263004e-10
# time took: 35.279492139816284 min
# experiment: 6 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_5
# [250.0, 500.0, 1000.0, 2000.0]
# epoch:1, step:1500, 1.2071012,1.6189933,1.8418283,1.9305598, accept_ratio:1.0, proba:1.1582334580793588e+77         32275465e-26
# /home/deep09/project_vlad/deep_tempering/simulation/simulation_builder/graph_builder.py:306: RuntimeWarning: overflow encountered in exp
#   accept_proba = np.exp((l1-l2)*(beta[i] - beta[j]))
# epoch:24, step:27500, 0.39141905,0.84237325,0.41302022,0.36285284, accept_ratio:0.28260869565217395, proba:3.256150995079785e-07
# time took: 35.25394665400187 min
# experiment: 7 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_6
# [250.0, 530.3300858899106, 1124.9999999999998, 2386.485386504597]
# epoch:24, step:27500, 0.7743445,0.3314223,0.35077524,0.39815196, accept_ratio:0.19565217391304351, proba:2.8427158764616384e+16
# time took: 35.28394201596578 min
# experiment: 8 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_7
# [250.0, 559.0169943749474, 1250.0000000000002, 2795.0849718747377]
# epoch:24, step:27500, 0.33469182,0.31984672,0.52624303,0.49083683, accept_ratio:0.15217391304347822, proba:7.01552082773233e+16
# time took: 35.39313371181488 min
# experiment: 9 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_8
# [250.0, 586.3019699779287, 1375.0, 3224.660834878608]
# epoch:24, step:27500, 0.5252876,0.97158396,0.34965694,0.24252915, accept_ratio:0.02173913043478261, proba:2.4315838403695243e-46
# time took: 35.34332661231359 min
# experiment: 10 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_9
# [250.0, 612.3724356957945, 1499.9999999999998, 3674.234614174766]
# epoch:24, step:27500, 0.7271441,0.5052912,0.23616228,0.36066398, accept_ratio:0.02173913043478261, proba:7.296562470561422e-39
# time took: 35.20786725282669 min
# experiment: 11 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_10
# [250.0, 637.377439199098, 1624.9999999999998, 4142.953354794136]
# epoch:24, step:27500, 0.8641322,0.30068344,0.36602283,0.30758077, accept_ratio:0.26086956521739124, proba:6.812420569026934e+23
# time took: 35.312542549769084 min
# experiment: 12 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_11
# [250.0, 661.4378277661477, 1750.0000000000002, 4630.064794363034]
# epoch:24, step:27500, 0.19463867,0.30040553,0.39035785,0.33667457, accept_ratio:0.391304347826087, proba:6.90783328118493e+28
# time took: 35.261986978848775 min
# experiment: 13 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_12
# [250.0, 684.6531968814577, 1875.0, 5134.898976610933]
# epoch:24, step:27500, 0.70628536,0.29158744,0.52774656,0.21222131, accept_ratio:0.02173913043478261, proba:3.012698851457407e-108
# time took: 35.25435217618942 min
# experiment: 14 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_13
# [250.0, 707.1067811865476, 2000.0000000000005, 5656.854249492381]
# epoch:24, step:27500, 0.37779072,0.43941513,0.5509124,0.81041414, accept_ratio:0.39130434782608686, proba:678446682065.7356
# time took: 35.51008659998576 min
# experiment: 15 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_14
# [250.0, 728.8689868556626, 2125.0, 6195.386388273133]
# epoch:24, step:27500, 0.46465772,0.8257547,0.2780419,0.21254842, accept_ratio:0.02173913043478261, proba:1.0325388260983715e-138
# time took: 35.40395116011302 min
# experiment: 16 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_15
# [250.0, 750.0, 2250.0, 6750.0]
# epoch:24, step:27500, 0.44640148,0.51401204,0.8127766,0.5078295, accept_ratio:0.3913043478260868, proba:9.077612817723684e+119
# time took: 35.34599573214849 min
# experiment: 17 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_16
# [250.0, 770.551750371122, 2374.9999999999995, 7320.241628525659]
# epoch:24, step:27500, 0.38061306,0.7460332,0.46617037,0.4598299, accept_ratio:0.39130434782608686, proba:8.849784701686198e-11
# time took: 35.46678392489751 min
# experiment: 18 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_17
# [250.0, 790.5694150420949, 2500.0000000000005, 7905.69415042095]
# epoch:24, step:27500, 0.474283,0.90818787,0.18514119,0.27363843, accept_ratio:0.08695652173913045, proba:3.39303801000544e-150
# time took: 35.408761489391324 min
# experiment: 19 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_18
# [250.0, 829.15619758885, 2750.0, 9120.71817347735]
# epoch:24, step:27500, 0.42287725,0.788236,0.2673236,0.18951021, accept_ratio:0.02173913043478261, proba:2.9372527538520894e-81
# time took: 35.43350039323171 min
# experiment: 20 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_19
# [250.0, 866.0254037844386, 2999.9999999999995, 10392.304845413262]
# epoch:24, step:27500, 0.17529924,0.31142583,0.41280547,0.28710786, accept_ratio:0.45652173913043465, proba:0.0         60963827
# time took: 35.44517535368602 min
# experiment: 21 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_20
# [250.0, 901.3878188659972, 3249.9999999999995, 11718.041645257965]
# epoch:24, step:27500, 0.7635718,0.24108428,0.4062796,0.18068703, accept_ratio:0.02173913043478261, proba:1.3459117539504195e-89
# time took: 35.46054100195567 min
# experiment: 22 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_21
# [250.0, 935.4143466934853, 3500.0, 13095.800853708795]
# epoch:24, step:27500, 0.20807754,0.26096877,0.33217514,0.279986, accept_ratio:0.36956521739130427, proba:0.0         08678e-05
# time took: 35.47025554180145 min
# experiment: 23 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_energy_250_22
# [250.0, 968.2458365518543, 3750.0000000000005, 14523.687548277814]
# epoch:24, step:27500, 0.7710344,0.22739075,0.3788983,0.17672355, accept_ratio:0.02173913043478261, proba:3.626012317855123e-106
# time took: 35.48809029658636 min

# %%
"""NN architecture"""

"""Experiment name:
    <arhictecture>_<dataset>_<tuning parameter>_<optimizer>_<dynamic=swaps occure/static=swaps don't occur>_
    <n_replicas>_<surface view>_<starting_beta_>"""

experiment_name = 'nn_mnist_tempfactor_PTLD_dynamic_4_information_250'
tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         np.sqrt(8),
                         np.sqrt(8.5),
                         np.sqrt(9),
                         np.sqrt(9.5),
                         np.sqrt(10),
                         np.sqrt(11),
                         np.sqrt(12),
                         np.sqrt(13),
                         np.sqrt(14),
                         np.sqrt(15)]

description = """Tuning of `temp_factor` with constant swap_attempt_step=600. 
Parralel Tempering Langevin Dynamics. 4 replicas
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 15
batch_size = 50
n_epochs = 25
swap_attempt_step = 600
surface_view = 'information'



print(tuning_parameter_vals)
start_time = time()
for exp in range(n_experiments):
    print('experiment:', exp+1, '/', n_experiments)
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [beta_0*temp_factor**i for i in range(n_replicas)]

    print(noise_list)
    
    sim = Simulator(nn_mnist_architecture, 
                    0.01, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    surface_view=surface_view,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 2.8284271247461903, 2.9154759474226504, 3.0, 3.082207001484488, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 3.872983346207417]
# experiment: 1 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_0
# [250.0, 306.18621784789724, 374.99999999999994, 459.2793267718458]
# epoch:24, step:27500, 1.541069,1.5119696,1.6471442,1.9697397, accept_ratio:0.9782608695652172, proba:1.002740209522471
# time took: 18.31732912460963 min
# experiment: 2 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_1
# [250.0, 353.5533905932738, 500.0000000000001, 707.1067811865477]
# epoch:24, step:27500, 1.3448805,1.3260363,1.4828521,1.7952679, accept_ratio:0.8913043478260865, proba:0.8879552986424314
# time took: 18.17396699587504 min
# experiment: 3 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_2
# [250.0, 395.28470752104744, 625.0000000000001, 988.2117688026187]
# epoch:24, step:27500, 1.3520688,1.6382843,1.5265447,1.426215, accept_ratio:0.7608695652173912, proba:0.8418782278664306
# time took: 18.19092160463333 min
# experiment: 4 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_3
# [250.0, 433.0127018922193, 749.9999999999999, 1299.0381056766578]
# epoch:24, step:27500, 1.0828083,1.3745704,1.5996112,1.6784779, accept_ratio:0.7173913043478262, proba:0.7350469246363537
# time took: 18.170371866226198 min
# experiment: 5 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_4
# [250.0, 467.70717334674265, 875.0, 1636.9751067135994]
# epoch:24, step:27500, 1.3021951,1.6024426,1.5398369,1.4793909, accept_ratio:0.5434782608695652, proba:0.48664301333737436
# time took: 17.98281854391098 min
# experiment: 6 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_5
# [250.0, 500.0, 1000.0, 2000.0]
# epoch:24, step:27500, 0.8974446,0.8074288,1.6333643,1.2819307, accept_ratio:0.49999999999999994, proba:0.2913618236256355
# time took: 17.975247514247894 min
# experiment: 7 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_6
# [250.0, 530.3300858899106, 1124.9999999999998, 2386.485386504597]
# epoch:24, step:27500, 0.93623245,1.2845689,0.69849575,1.08769, accept_ratio:0.43478260869565216, proba:0.68862560168174
# time took: 18.021222190062204 min
# experiment: 8 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_7
# [250.0, 559.0169943749474, 1250.0000000000002, 2795.0849718747377]
# epoch:24, step:27500, 0.7169745,1.6946365,1.8096273,1.5731534, accept_ratio:0.28260869565217384, proba:0.3569777823587189
# time took: 17.867283765474955 min
# experiment: 9 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_8
# [250.0, 586.3019699779287, 1375.0, 3224.660834878608]
# epoch:24, step:27500, 0.67854786,2.0922768,1.3070112,1.5741998, accept_ratio:0.2173913043478261, proba:0.3261064607457639
# time took: 17.838876879215242 min
# experiment: 10 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_9
# [250.0, 612.3724356957945, 1499.9999999999998, 3674.234614174766]
# epoch:24, step:27500, 2.1273742,0.55022013,1.0781902,1.0863262, accept_ratio:0.28260869565217384, proba:1.1253512251960354
# time took: 17.836014533042906 min
# experiment: 11 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_10
# [250.0, 637.377439199098, 1624.9999999999998, 4142.953354794136]
# epoch:24, step:27500, 1.0300301,1.0250088,1.5906227,1.3867949, accept_ratio:0.28260869565217384, proba:0.14527106295093686
# time took: 17.81355084180832 min
# experiment: 12 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_11
# [250.0, 661.4378277661477, 1750.0000000000002, 4630.064794363034]
# epoch:24, step:27500, 0.3861976,2.0906808,1.487123,1.3127346, accept_ratio:0.13043478260869565, proba:0.135901753732914
# time took: 17.698756869633993 min
# experiment: 13 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_12
# [250.0, 684.6531968814577, 1875.0, 5134.898976610933]
# epoch:24, step:27500, 1.9016196,0.49022877,0.7692943,0.6170342, accept_ratio:0.3913043478260869, proba:0.714668448169846
# time took: 17.719756094614663 min
# experiment: 14 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_13
# [250.0, 707.1067811865476, 2000.0000000000005, 5656.854249492381]
# epoch:24, step:27500, 1.540149,0.51031274,0.8724647,1.6564593, accept_ratio:0.3043478260869565, proba:0.29554454797846347
# time took: 17.713443394502004 min
# experiment: 15 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_14
# [250.0, 728.8689868556626, 2125.0, 6195.386388273133]
# epoch:24, step:27500, 2.029064,0.53261435,0.84055644,0.7851413, accept_ratio:0.39130434782608686, proba:0.7135294136911791
# time took: 17.666227602958678 min
# experiment: 16 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_15
# [250.0, 750.0, 2250.0, 6750.0]
# epoch:24, step:27500, 0.48984054,1.6803969,0.29482275,1.0830501, accept_ratio:0.17391304347826084, proba:0.25655147580747417
# time took: 17.698672846953073 min
# experiment: 17 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_16
# [250.0, 770.551750371122, 2374.9999999999995, 7320.241628525659]
# epoch:24, step:27500, 0.3624079,1.0515243,0.9386188,1.0914671, accept_ratio:0.1739130434782609, proba:0.13758882366436656
# time took: 17.75936987797419 min
# experiment: 18 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_17
# [250.0, 790.5694150420949, 2500.0000000000005, 7905.69415042095]
# epoch:24, step:27500, 1.1231008,1.9595664,0.26548764,0.5080457, accept_ratio:0.23913043478260868, proba:0.0674915419665108
# time took: 17.722324645519258 min
# experiment: 19 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_18
# [250.0, 829.15619758885, 2750.0, 9120.71817347735]
# epoch:24, step:27500, 0.46495908,1.1087487,1.1456136,0.8773732, accept_ratio:0.15217391304347822, proba:0.041290053852017096
# time took: 17.688700910409292 min
# experiment: 20 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_19
# [250.0, 866.0254037844386, 2999.9999999999995, 10392.304845413262]
# epoch:24, step:27500, 1.8750262,0.36943963,0.7338209,0.4648565, accept_ratio:0.39130434782608686, proba:0.6981905871693428
# time took: 17.70240426460902 min
# experiment: 21 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_20
# [250.0, 901.3878188659972, 3249.9999999999995, 11718.041645257965]
# epoch:24, step:27500, 2.0217276,0.38291696,0.77715486,1.0059158, accept_ratio:0.19565217391304346, proba:0.011012903342179341
# time took: 17.661986827850342 min
# experiment: 22 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_21
# [250.0, 935.4143466934853, 3500.0, 13095.800853708795]
# epoch:24, step:27500, 1.7310793,1.4199461,0.22301723,0.3939084, accept_ratio:0.2826086956521739, proba:0.40778051197251103
# time took: 17.669299825032553 min
# experiment: 23 / 23
# nn_mnist_tempfactor_PTLD_dynamic_4_information_250_22
# [250.0, 968.2458365518543, 3750.0000000000005, 14523.687548277814]
# epoch:24, step:27500, 1.9927664,0.5342423,0.8315242,0.3710855, accept_ratio:0.23913043478260862, proba:0.004299626314208317
# time took: 17.67781726519267 min

# %%
"""CNN architecture"""

"""Experiment name:
    <arhictecture>_<dataset>_<tuning parameter>_<optimizer>_<dynamic=swaps occure/static=swaps don't occur>_
    <n_replicas>_<surface view>_<starting_beta_>"""

experiment_name = 'cnn_mnist_tempfactor_PTLD_dynamic_4_information_250'

tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         np.sqrt(8),
                         np.sqrt(8.5),
                         np.sqrt(9),
                         np.sqrt(9.5),
                         np.sqrt(10),
                         np.sqrt(11),
                         np.sqrt(12),
                         np.sqrt(13),
                         np.sqrt(14),
                         np.sqrt(15)]

description = """Tuning of `temp_factor` with constant swap_attempt_step=600. 
Parralel Tempering Langevin Dynamics. 4 replicas
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 15
batch_size = 50
n_epochs = 25
swap_attempt_step = 600
surface_view='information'




print(tuning_parameter_vals)
start_time = time()
for exp in range(n_experiments):
    print('experiment:', exp+1, '/', n_experiments)
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [beta_0*temp_factor**i for i in range(n_replicas)]

    print(noise_list)
    
    sim = Simulator(cnn_mnist_architecture2, 
                    0.001, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    surface_view=surface_view,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 2.8284271247461903, 2.9154759474226504, 3.0, 3.082207001484488, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 3.872983346207417]
# experiment: 1 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_0
# [250.0, 306.18621784789724, 374.99999999999994, 459.2793267718458]
# epoch:24, step:27500, 0.69320476,0.97033495,0.84433496,0.73708606, accept_ratio:0.9130434782608694, proba:0.9720907021476957
# time took: 36.5662753979365 min
# experiment: 2 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_1
# [250.0, 353.5533905932738, 500.0000000000001, 707.1067811865477]
# epoch:24, step:27500, 0.7687412,0.9520753,0.69367236,0.55309665, accept_ratio:0.9347826086956519, proba:0.8719593015984856
# time took: 36.73399088382721 min
# experiment: 3 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_2
# [250.0, 395.28470752104744, 625.0000000000001, 988.2117688026187]
# epoch:24, step:27500, 0.4625982,0.7806079,0.742371,0.72981006, accept_ratio:0.8695652173913042, proba:0.9409733865090564
# time took: 36.59208164612452 min
# experiment: 4 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_3
# [250.0, 433.0127018922193, 749.9999999999999, 1299.0381056766578]
# epoch:24, step:27500, 0.47457138,0.42500302,0.71093005,0.5012834, accept_ratio:0.8043478260869562, proba:0.8688334828396161
# time took: 36.59235926071803 min
# experiment: 5 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_4
# [250.0, 467.70717334674265, 875.0, 1636.9751067135994]
# epoch:24, step:27500, 0.35779223,0.50395155,0.45838994,0.5112017, accept_ratio:0.7391304347826089, proba:0.8822319400518981
# time took: 36.62426402171453 min
# experiment: 6 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_5
# [250.0, 500.0, 1000.0, 2000.0]
# epoch:24, step:27500, 0.5793443,0.8140436,0.38100365,0.44740376, accept_ratio:0.7173913043478262, proba:0.8745991062216378
# time took: 36.52590155204137 min
# experiment: 7 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_6
# [250.0, 530.3300858899106, 1124.9999999999998, 2386.485386504597]
# epoch:24, step:27500, 0.30033028,0.45413646,0.41141766,0.627956, accept_ratio:0.5869565217391305, proba:0.589197413926204
# time took: 36.48882712920507 min
# experiment: 8 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_7
# [250.0, 559.0169943749474, 1250.0000000000002, 2795.0849718747377]
# epoch:24, step:27500, 0.368065,0.39337608,0.4648066,0.57327616, accept_ratio:0.6521739130434782, proba:0.795560237953418
# time took: 36.524017572402954 min
# experiment: 9 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_8
# [250.0, 586.3019699779287, 1375.0, 3224.660834878608]
# epoch:24, step:27500, 0.34771436,0.7363879,0.30863735,0.6696973, accept_ratio:0.652173913043478, proba:0.5503964454564221
# time took: 36.42933411598206 min
# experiment: 10 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_9
# [250.0, 612.3724356957945, 1499.9999999999998, 3674.234614174766]
# epoch:24, step:27500, 0.4864541,0.4435334,0.55143946,0.59373075, accept_ratio:0.45652173913043487, proba:0.714080712157697
# time took: 36.40984550317128 min
# experiment: 11 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_10
# [250.0, 637.377439199098, 1624.9999999999998, 4142.953354794136]
# epoch:24, step:27500, 0.24929476,0.30027375,0.37884367,0.53591657, accept_ratio:0.5869565217391304, proba:0.5198603952692421
# time took: 36.18445995251338 min
# experiment: 12 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_11
# [250.0, 661.4378277661477, 1750.0000000000002, 4630.064794363034]
# epoch:24, step:27500, 0.26002178,0.75350136,0.59287024,0.45711675, accept_ratio:0.5652173913043479, proba:0.7436861168396538
# time took: 36.35684957901637 min
# experiment: 13 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_12
# [250.0, 684.6531968814577, 1875.0, 5134.898976610933]
# epoch:24, step:27500, 0.33384115,0.38031211,0.59967744,0.49380538, accept_ratio:0.5652173913043481, proba:0.7470476156593724
# time took: 36.34599966605504 min
# experiment: 14 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_13
# [250.0, 707.1067811865476, 2000.0000000000005, 5656.854249492381]
# epoch:24, step:27500, 0.5267187,0.4997038,0.5049753,0.5164048, accept_ratio:0.5869565217391305, proba:0.48349856334495195
# time took: 36.30223457018534 min
# experiment: 15 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_14
# [250.0, 728.8689868556626, 2125.0, 6195.386388273133]
# epoch:24, step:27500, 0.343083,0.4336543,0.8122834,0.6536177, accept_ratio:0.2826086956521739, proba:0.9056789170813763
# time took: 36.19355608224869 min
# experiment: 16 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_15
# [250.0, 750.0, 2250.0, 6750.0]
# epoch:24, step:27500, 0.30605903,0.36636874,0.48390663,0.41671583, accept_ratio:0.2826086956521738, proba:0.5110205002500907
# time took: 36.241872588793434 min
# experiment: 17 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_16
# [250.0, 770.551750371122, 2374.9999999999995, 7320.241628525659]
# epoch:24, step:27500, 0.42291144,0.34916088,0.39074564,0.377879, accept_ratio:0.4130434782608694, proba:0.5336847746742682
# time took: 36.04179721673329 min
# experiment: 18 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_17
# [250.0, 790.5694150420949, 2500.0000000000005, 7905.69415042095]
# epoch:24, step:27500, 0.3750251,0.17676574,0.84175205,0.9240559, accept_ratio:0.30434782608695654, proba:0.2324781848192473
# time took: 36.14480375846227 min
# experiment: 19 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_18
# [250.0, 829.15619758885, 2750.0, 9120.71817347735]
# epoch:24, step:27500, 0.6815714,0.24032435,0.4293119,0.48283184, accept_ratio:0.32608695652173914, proba:0.4328855412070772
# time took: 36.09224149783452 min
# experiment: 20 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_19
# [250.0, 866.0254037844386, 2999.9999999999995, 10392.304845413262]
# epoch:24, step:27500, 0.80977273,0.22032456,0.31130862,0.33818987, accept_ratio:0.3913043478260868, proba:0.17903575836763727
# time took: 36.10644678672155 min
# experiment: 21 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_20
# [250.0, 901.3878188659972, 3249.9999999999995, 11718.041645257965]
# epoch:24, step:27500, 0.402034,0.7630128,0.59609705,0.2591516, accept_ratio:0.4565217391304348, proba:0.964945638906745
# time took: 36.0772771080335 min
# experiment: 22 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_21
# [250.0, 935.4143466934853, 3500.0, 13095.800853708795]
# epoch:24, step:27500, 0.35526016,0.5995692,0.7970593,0.77925205, accept_ratio:0.2391304347826087, proba:0.5760532898681443
# time took: 36.22697175343831 min
# experiment: 23 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_4_information_250_22
# [250.0, 968.2458365518543, 3750.0000000000005, 14523.687548277814]
# epoch:24, step:27500, 0.4319598,0.21266744,0.46935204,0.73195297, accept_ratio:0.3695652173913043, proba:0.7589002393084786
# time took: 36.10529155333837 min

# %%
"""EXPERIMENT 4










n_replicas = 6
starts at beta = 250



















"""
beta_0 = 250
n_replicas = 6

# %%
"""NN architecture """

experiment_name = 'nn_mnist_tempfactor_PTLD_dynamic_6_energy_250'

"""Experiment name:
    <arhictecture>_<dataset>_<tuning parameter>_<optimizer>_<dynamic=swaps occure/static=swaps don't occur>_
    <n_replicas>_<surface view>_<starting_beta_>"""


tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         np.sqrt(8),
                         np.sqrt(8.5),
                         np.sqrt(9),
                         np.sqrt(9.5),
                         np.sqrt(10),
                         np.sqrt(11),
                         np.sqrt(12),
                         np.sqrt(13),
                         np.sqrt(14),
                         np.sqrt(15)]

description = """Tuning of `temp_factor` with constant swap_attempt_step=600. 
Parralel Tempering Langevin Dynamics. 6 replicas
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 15
batch_size = 50
n_epochs = 25
swap_attempt_step = 600
surface_view = 'energy'


print(tuning_parameter_vals)
start_time = time()
for exp in range(n_experiments):
    print('experiment:', exp+1, '/', n_experiments)
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [beta_0*temp_factor**i for i in range(n_replicas)]

    print(noise_list)
    
    sim = Simulator(nn_mnist_architecture, 
                    0.01, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    surface_view=surface_view,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 2.8284271247461903, 2.9154759474226504, 3.0, 3.082207001484488, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 3.872983346207417]
# experiment: 1 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_0
# [250.0, 306.18621784789724, 374.99999999999994, 459.2793267718458, 562.4999999999998, 688.9189901577686]
# epoch:24, step:27500, 2.0249298,1.5006545,1.3218278,1.6848414,1.1572689,1.0861592, accept_ratio:0.06521739130434782, proba:0.4456680141830489
# time took: 26.198113318284353 min
# experiment: 2 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_1
# [250.0, 353.5533905932738, 500.0000000000001, 707.1067811865477, 1000.0000000000002, 1414.2135623730956]
# epoch:24, step:27500, 2.0041523,1.5109925,1.3858757,0.9756168,0.7814718,0.5879264, accept_ratio:0.0, proba:9.641537306071968e-09             3e-13
# time took: 25.86548787355423 min
# experiment: 3 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_2
# [250.0, 395.28470752104744, 625.0000000000001, 988.2117688026187, 1562.5000000000005, 2470.529422006547]
# epoch:24, step:27500, 1.9562321,1.5006832,1.1364465,0.8480494,0.63014734,0.4588621, accept_ratio:0.0, proba:5.811678747481602e-59            e-45
# time took: 25.866858859856922 min
# experiment: 4 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_3
# [250.0, 433.0127018922193, 749.9999999999999, 1299.0381056766578, 2249.9999999999995, 3897.114317029973]
# epoch:24, step:27500, 1.961616,1.3410902,0.9944161,0.70173293,0.5039234,0.36835414, accept_ratio:0.0, proba:2.26428604579418e-132             2e-101
# time took: 25.880917096138 min
# experiment: 5 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_4
# [250.0, 467.70717334674265, 875.0, 1636.9751067135994, 3062.5, 5729.4128734975975]
# epoch:24, step:27500, 2.0698352,1.3050292,0.8501163,0.5824384,0.41130254,0.32587555, accept_ratio:0.0, proba:4.121940574700424e-105           e-67
# time took: 25.893641579151154 min
# experiment: 6 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_5
# [250.0, 500.0, 1000.0, 2000.0, 4000.0, 8000.0]
# epoch:24, step:27500, 2.0693707,0.7765072,1.2666874,0.6046046,0.41303867,0.269976, accept_ratio:0.02173913043478261, proba:1.1752261447770579e-158
# time took: 25.917314155896506 min
# experiment: 7 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_6
# [250.0, 530.3300858899106, 1124.9999999999998, 2386.485386504597, 5062.499999999998, 10739.184239270686]
# epoch:24, step:27500, 2.1407745,1.1564771,0.8393872,0.48128423,0.32193217,0.24942143, accept_ratio:0.0, proba:1.6710459008718267e-226          -196
# /home/deep09/project_vlad/deep_tempering/simulation/simulation_builder/graph_builder.py:306: RuntimeWarning: overflow encountered in exp
#   accept_proba = np.exp((l1-l2)*(beta[i] - beta[j]))
# epoch:24, step:27500, 1.9983307,1.2397761,0.49714956,0.7511321,0.36466098,0.22777763, accept_ratio:0.02173913043478261, proba:1.1452889153783972e-122
# time took: 25.915799323717753 min
# experiment: 8 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_7
# [250.0, 559.0169943749474, 1250.0000000000002, 2795.0849718747377, 6250.000000000001, 13975.424859373688]
# epoch:24, step:27500, 1.1643976,1.9267055,0.64371705,0.44941387,0.31622887,0.22137494, accept_ratio:0.02173913043478261, proba:6.499971597907374e-110
# time took: 25.934787956873574 min
# experiment: 9 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_8
# [250.0, 586.3019699779287, 1375.0, 3224.660834878608, 7562.500000000001, 17735.634591832346]
# epoch:24, step:27500, 1.9257011,1.0681152,0.41212997,0.6981657,0.28193116,0.19595467, accept_ratio:0.02173913043478261, proba:0.0         266999e-302
# time took: 25.961303909619648 min
# experiment: 10 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_9
# [250.0, 612.3724356957945, 1499.9999999999998, 3674.234614174766, 8999.999999999996, 22045.407685048594]
# epoch:24, step:27500, 1.891928,1.416158,0.62149113,0.40144107,0.1818284,0.2611394, accept_ratio:0.02173913043478261, proba:2.4189164374739256e-210
# time took: 25.973137986660003 min
# experiment: 11 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_10
# [250.0, 637.377439199098, 1624.9999999999998, 4142.953354794136, 10562.499999999996, 26929.196806161886]
# epoch:24, step:27500, 2.1659145,0.97184795,0.561093,0.36275488,0.24130762,0.15823795, accept_ratio:0.0, proba:2.391503454566631e-185           e-218
# time took: 25.978222461541495 min
# experiment: 12 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_11
# [250.0, 661.4378277661477, 1750.0000000000002, 4630.064794363034, 12250.000000000002, 32410.453560541242]
# epoch:24, step:27500, 1.883209,1.1307274,0.33442402,0.57426524,0.21638022,0.1519257, accept_ratio:0.02173913043478261, proba:3.2443756639317414e-169
# time took: 26.001791214942934 min
# experiment: 13 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_12
# [250.0, 684.6531968814577, 1875.0, 5134.898976610933, 14062.5, 38511.742324581995]
# epoch:24, step:27500, 2.209775,1.0014855,0.55127853,0.32401177,0.21430136,0.13737193, accept_ratio:0.0, proba:0.0         06426e-259           245
# time took: 26.0198206782341 min
# experiment: 14 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_13
# [250.0, 707.1067811865476, 2000.0000000000005, 5656.854249492381, 16000.000000000004, 45254.83399593906]
# epoch:24, step:27500, 2.1110601,1.0288527,0.5184749,0.19697946,0.29091185,0.13035315, accept_ratio:0.02173913043478261, proba:1.602865388435684e-266
# time took: 26.034370875358583 min
# experiment: 15 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_14
# [250.0, 728.8689868556626, 2125.0, 6195.386388273133, 18062.500000000004, 52660.78430032163]
# epoch:24, step:27500, 1.8487129,1.0293229,0.48943383,0.31580088,0.12316011,0.20393355, accept_ratio:0.02173913043478261, proba:1.4505492528073148e-288
# time took: 26.06234664916992 min
# experiment: 16 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_15
# [250.0, 750.0, 2250.0, 6750.0, 20250.0, 60750.0]
# epoch:24, step:27500, 2.0107605,0.97893065,0.29899204,0.47778612,0.17950222,0.13560042, accept_ratio:0.02173913043478261, proba:1.2285986445399382e-246
# time took: 26.072931186358133 min
# experiment: 17 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_16
# [250.0, 770.551750371122, 2374.9999999999995, 7320.241628525659, 22562.499999999993, 69542.29547099373]
# epoch:24, step:27500, 2.08472,1.0597867,0.4856737,0.3027751,0.11886549,0.17552276, accept_ratio:0.02173913043478261, proba:0.0               824e-232
# time took: 26.081596918900807 min
# experiment: 18 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_17
# [250.0, 790.5694150420949, 2500.0000000000005, 7905.69415042095, 25000.000000000007, 79056.9415042095]
# epoch:24, step:27500, 2.2390473,0.85602725,0.45214057,0.2688412,0.16741309,0.11280819, accept_ratio:0.0, proba:1.79078617577e-312               3e-279
# time took: 26.09459249575933 min
# experiment: 19 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_18
# [250.0, 829.15619758885, 2750.0, 9120.71817347735, 30250.0, 100327.89990825084]
# epoch:24, step:27500, 1.9738342,0.9703383,0.46883428,0.2575917,0.10678724,0.15262051, accept_ratio:0.02173913043478261, proba:0.0            57e-283
# time took: 26.113940636316936 min
# experiment: 20 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_19
# [250.0, 866.0254037844386, 2999.9999999999995, 10392.304845413262, 35999.99999999999, 124707.65814495913]
# epoch:24, step:27500, 0.96502835,2.0800557,0.4392609,0.25903484,0.13649009,0.11037237, accept_ratio:0.02173913043478261, proba:1.2644828090477168e-298
# time took: 26.089911456902822 min
# experiment: 21 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_20
# [250.0, 901.3878188659972, 3249.9999999999995, 11718.041645257965, 42249.99999999999, 152334.5413883535]
# epoch:24, step:27500, 1.993718,0.87114453,0.22457683,0.42907247,0.13115178,0.09691345, accept_ratio:0.02173913043478261, proba:0.0           e-257
# time took: 26.125170548756916 min
# experiment: 22 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_21
# [250.0, 935.4143466934853, 3500.0, 13095.800853708795, 49000.0, 183341.21195192312]
# epoch:24, step:27500, 2.0765095,0.8723713,0.21155532,0.40956753,0.12746201,0.09849331, accept_ratio:0.02173913043478261, proba:0.0           12
# time took: 26.147747365633645 min
# experiment: 23 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_energy_250_22
# [250.0, 968.2458365518543, 3750.0000000000005, 14523.687548277814, 56250.00000000001, 217855.31322416724]
# epoch:24, step:27500, 1.9563156,0.7191331,0.19644058,0.36443827,0.13226275,0.097021356, accept_ratio:0.02173913043478261, proba:0.0
# time took: 26.22268665631612 min

# %%
"""CNN architecture"""

"""Experiment name:
    <arhictecture>_<dataset>_<tuning parameter>_<optimizer>_<dynamic=swaps occure/static=swaps don't occur>_
    <n_replicas>_<surface view>_<starting_beta_>"""

experiment_name = 'cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250'

tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         np.sqrt(8),
                         np.sqrt(8.5),
                         np.sqrt(9),
                         np.sqrt(9.5),
                         np.sqrt(10),
                         np.sqrt(11),
                         np.sqrt(12),
                         np.sqrt(13),
                         np.sqrt(14),
                         np.sqrt(15)]

description = """Tuning of `temp_factor` with constant swap_attempt_step=600. 
Parralel Tempering Langevin Dynamics. 6 replicas
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 15
batch_size = 50
n_epochs = 25
swap_attempt_step = 600
surface_view='energy'




print(tuning_parameter_vals)
start_time = time()
for exp in range(n_experiments):
    print('experiment:', exp+1, '/', n_experiments)
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [beta_0*temp_factor**i for i in range(n_replicas)]

    print(noise_list)
    
    sim = Simulator(cnn_mnist_architecture2, 
                    0.001, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    surface_view=surface_view,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 2.8284271247461903, 2.9154759474226504, 3.0, 3.082207001484488, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 3.872983346207417]
# experiment: 1 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_0
# [250.0, 306.18621784789724, 374.99999999999994, 459.2793267718458, 562.4999999999998, 688.9189901577686]
# epoch:24, step:27500, 0.56027,0.70634794,0.59026486,0.72607327,0.53630525,0.4863015, accept_ratio:0.13043478260869562, proba:0.004397426251220135
# time took: 53.75248244603475 min
# experiment: 2 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_1
# [250.0, 353.5533905932738, 500.0000000000001, 707.1067811865477, 1000.0000000000002, 1414.2135623730956]
# epoch:24, step:27500, 0.65861624,0.7649469,0.8521052,0.8045841,0.34439823,0.40554732, accept_ratio:0.217391304347826, proba:1966462859735.7253
# time took: 53.16739193201065 min
# experiment: 3 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_2
# [250.0, 395.28470752104744, 625.0000000000001, 988.2117688026187, 1562.5000000000005, 2470.529422006547]
# epoch:24, step:27500, 0.8191454,0.50328106,0.69122636,0.41833174,0.2551747,0.31063384, accept_ratio:0.04347826086956522, proba:5.599230834553716e-30
# time took: 53.523711919784546 min
# experiment: 4 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_3
# [250.0, 433.0127018922193, 749.9999999999999, 1299.0381056766578, 2249.9999999999995, 3897.114317029973]
# epoch:24, step:27500, 0.78448886,0.45090443,0.5834063,0.26666892,0.32854277,0.22089024, accept_ratio:0.08695652173913045, proba:7.539454909476992e-32
# time took: 53.15881206591924 min
# experiment: 5 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_4
# [250.0, 467.70717334674265, 875.0, 1636.9751067135994, 3062.5, 5729.4128734975975]
# epoch:1, step:1500, 1.0546535,1.3769673,1.6346047,1.2537624,1.4408039,1.8287907, accept_ratio:0.3333333333333333, proba:4.5716511802883664e-05
# /home/deep09/project_vlad/deep_tempering/simulation/simulation_builder/graph_builder.py:306: RuntimeWarning: overflow encountered in exp
#   accept_proba = np.exp((l1-l2)*(beta[i] - beta[j]))
# epoch:24, step:27500, 0.84615135,0.59538895,0.25218698,0.24167329,0.3420743,0.33386767, accept_ratio:0.3043478260869565, proba:3.922158371685605e-26
# time took: 53.52865244547526 min
# experiment: 6 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_5
# [250.0, 500.0, 1000.0, 2000.0, 4000.0, 8000.0]
# epoch:24, step:27500, 0.25857842,0.27248257,0.33725595,0.5396533,0.4811675,0.5090297, accept_ratio:0.3695652173913042, proba:1.1925490056967319e-43
# time took: 53.52016146580378 min
# experiment: 7 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_6
# [250.0, 530.3300858899106, 1124.9999999999998, 2386.485386504597, 5062.499999999998, 10739.184239270686]
# epoch:24, step:27500, 0.84074944,0.48492226,0.37880528,0.27489388,0.19712175,0.19728848, accept_ratio:0.06521739130434784, proba:4.889965561219826e-42
# time took: 53.233363318443295 min
# experiment: 8 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_7
# [250.0, 559.0169943749474, 1250.0000000000002, 2795.0849718747377, 6250.000000000001, 13975.424859373688]
# epoch:24, step:27500, 0.7117211,0.24417695,0.64445126,0.5451425,0.16919594,0.2061561, accept_ratio:0.10869565217391303, proba:5.813740324543979e-135
# time took: 53.4608668367068 min
# experiment: 9 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_8
# [250.0, 586.3019699779287, 1375.0, 3224.660834878608, 7562.500000000001, 17735.634591832346]
# epoch:24, step:27500, 0.5088624,0.73030055,0.23279439,0.32957315,0.18502387,0.17369731, accept_ratio:0.04347826086956522, proba:2.048486616881998e-54
# time took: 53.45314155419668 min
# experiment: 10 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_9
# [250.0, 612.3724356957945, 1499.9999999999998, 3674.234614174766, 8999.999999999996, 22045.407685048594]
# epoch:24, step:27500, 0.49218604,1.0180051,0.34213147,0.23125815,0.1861469,0.15268137, accept_ratio:0.02173913043478261, proba:3.811461971349633e-116
# time took: 53.47585537433624 min
# experiment: 11 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_10
# [250.0, 637.377439199098, 1624.9999999999998, 4142.953354794136, 10562.499999999996, 26929.196806161886]
# epoch:24, step:27500, 0.31125572,0.33523232,0.4695173,0.22458199,0.1633733,0.18636003, accept_ratio:0.0869565217391304, proba:1.4802225318075238e-21
# time took: 53.52310964266459 min
# experiment: 12 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_11
# [250.0, 661.4378277661477, 1750.0000000000002, 4630.064794363034, 12250.000000000002, 32410.453560541242]
# epoch:24, step:27500, 0.7245454,0.5319742,0.30370864,0.16945544,0.16903435,0.18230727, accept_ratio:0.19565217391304346, proba:1.5401231490040917e-63
# time took: 53.285249292850494 min
# experiment: 13 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_12
# [250.0, 684.6531968814577, 1875.0, 5134.898976610933, 14062.5, 38511.742324581995]
# epoch:24, step:27500, 0.4494373,0.8213057,0.29347467,0.154268,0.177167,0.17248501, accept_ratio:0.19565217391304346, proba:1.5738891253453847e-87
# time took: 53.60311240752538 min
# experiment: 14 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_13
# [250.0, 707.1067811865476, 2000.0000000000005, 5656.854249492381, 16000.000000000004, 45254.83399593906]
# epoch:24, step:27500, 0.88270783,0.42996478,0.20792402,0.27512425,0.28280875,0.15142605, accept_ratio:0.06521739130434785, proba:3.804709912453688e-102
# time took: 53.716119356950124 min
# experiment: 15 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_14
# [250.0, 728.8689868556626, 2125.0, 6195.386388273133, 18062.500000000004, 52660.78430032163]
# epoch:24, step:27500, 0.4941033,0.7986519,0.17180887,0.31915727,0.20399724,0.17996453, accept_ratio:0.2608695652173913, proba:3.967980366923573e-69
# time took: 53.626616362730665 min
# experiment: 16 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_15
# [250.0, 750.0, 2250.0, 6750.0, 20250.0, 60750.0]
# epoch:24, step:27500, 0.88223976,0.27061322,0.33132958,0.26908588,0.1524243,0.15835276, accept_ratio:0.1739130434782609, proba:9.296397413181538e-125
# time took: 53.689456446965536 min
# experiment: 17 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_16
# [250.0, 770.551750371122, 2374.9999999999995, 7320.241628525659, 22562.499999999993, 69542.29547099373]
# epoch:24, step:27500, 0.83804864,0.45708832,0.2561933,0.16250002,0.162993,0.17138837, accept_ratio:0.13043478260869562, proba:1.6501432520561998e-71
# time took: 53.893445348739625 min
# experiment: 18 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_17
# [250.0, 790.5694150420949, 2500.0000000000005, 7905.69415042095, 25000.000000000007, 79056.9415042095]
# epoch:24, step:27500, 0.82915896,0.26820835,0.4587186,0.17139928,0.18430594,0.18747418, accept_ratio:0.19565217391304346, proba:1.0548613401799204e-68
# time took: 53.54914854367574 min
# experiment: 19 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_18
# [250.0, 829.15619758885, 2750.0, 9120.71817347735, 30250.0, 100327.89990825084]
# epoch:24, step:27500, 0.87558645,0.1561944,0.46876478,0.17430948,0.20344965,0.15063049, accept_ratio:0.1739130434782608, proba:2.230347700026525e-30
# time took: 53.97775932153066 min
# experiment: 20 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_19
# [250.0, 866.0254037844386, 2999.9999999999995, 10392.304845413262, 35999.99999999999, 124707.65814495913]
# epoch:24, step:27500, 0.24654643,0.25065663,0.45076337,0.16163781,0.18936726,0.18854782, accept_ratio:0.26086956521739113, proba:1.9464548017810642e-279
# time took: 53.79209374586741 min
# experiment: 21 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_20
# [250.0, 901.3878188659972, 3249.9999999999995, 11718.041645257965, 42249.99999999999, 152334.5413883535]
# epoch:24, step:27500, 1.0267874,0.4348084,0.17247151,0.20155844,0.19514675,0.19860531, accept_ratio:0.3695652173913044, proba:inf         9736206e-226
# time took: 53.95797441403071 min
# experiment: 22 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_21
# [250.0, 935.4143466934853, 3500.0, 13095.800853708795, 49000.0, 183341.21195192312]
# epoch:24, step:27500, 0.4387285,0.838621,0.22205186,0.16625573,0.17765507,0.1631462, accept_ratio:0.2826086956521739, proba:2.1645425148251587e+89
# time took: 54.18794473012289 min
# experiment: 23 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_energy_250_22
# [250.0, 968.2458365518543, 3750.0000000000005, 14523.687548277814, 56250.00000000001, 217855.31322416724]
# epoch:24, step:27500, 0.89177656,0.22287232,0.41102305,0.1647695,0.17320652,0.16727939, accept_ratio:0.13043478260869565, proba:4.472490649507436e-19
# time took: 53.9251990199089 min

# %%
"""NN architecture"""

"""Experiment name:
    <arhictecture>_<dataset>_<tuning parameter>_<optimizer>_<dynamic=swaps occure/static=swaps don't occur>_
    <n_replicas>_<surface view>_<starting_beta_>"""

experiment_name = 'nn_mnist_tempfactor_PTLD_dynamic_6_information_250'
tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         np.sqrt(8),
                         np.sqrt(8.5),
                         np.sqrt(9),
                         np.sqrt(9.5),
                         np.sqrt(10),
                         np.sqrt(11),
                         np.sqrt(12),
                         np.sqrt(13),
                         np.sqrt(14),
                         np.sqrt(15)]

description = """Tuning of `temp_factor` with constant swap_attempt_step=600. 
Parralel Tempering Langevin Dynamics. 6 replicas
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 15
batch_size = 50
n_epochs = 25
swap_attempt_step = 600
surface_view = 'information'



print(tuning_parameter_vals)
start_time = time()
for exp in range(n_experiments):
    print('experiment:', exp+1, '/', n_experiments)
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [beta_0*temp_factor**i for i in range(n_replicas)]

    print(noise_list)
    
    sim = Simulator(nn_mnist_architecture, 
                    0.01, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    surface_view=surface_view,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 2.8284271247461903, 2.9154759474226504, 3.0, 3.082207001484488, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 3.872983346207417]
# experiment: 1 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_0
# [250.0, 306.18621784789724, 374.99999999999994, 459.2793267718458, 562.4999999999998, 688.9189901577686]
# epoch:24, step:27500, 1.4000543,1.4909672,1.8251629,1.6022291,1.7372441,1.3181516, accept_ratio:0.8695652173913041, proba:0.9090715830030972
# time took: 29.145648539066315 min
# experiment: 2 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_1
# [250.0, 353.5533905932738, 500.0000000000001, 707.1067811865477, 1000.0000000000002, 1414.2135623730956]
# epoch:24, step:27500, 0.8822038,1.198521,1.6515572,1.4452976,1.3208472,1.5015454, accept_ratio:0.8695652173913042, proba:1.0761148910574299
# time took: 28.869041721026104 min
# experiment: 3 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_2
# [250.0, 395.28470752104744, 625.0000000000001, 988.2117688026187, 1562.5000000000005, 2470.529422006547]
# epoch:24, step:27500, 1.2781541,1.2089967,0.70877725,1.1983765,1.3102586,0.9976773, accept_ratio:0.8043478260869562, proba:0.7348360544514801
# time took: 28.539729042847952 min
# experiment: 4 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_3
# [250.0, 433.0127018922193, 749.9999999999999, 1299.0381056766578, 2249.9999999999995, 3897.114317029973]
# epoch:24, step:27500, 1.2370901,1.2683372,0.48992744,1.8197844,0.7562283,1.1711732, accept_ratio:0.6956521739130438, proba:0.721839030162599
# time took: 28.388423864046732 min
# experiment: 5 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_4
# [250.0, 467.70717334674265, 875.0, 1636.9751067135994, 3062.5, 5729.4128734975975]
# epoch:24, step:27500, 0.9887723,0.89893615,1.427664,1.8265541,1.8991574,0.73180234, accept_ratio:0.4782608695652173, proba:0.9152321303087725
# time took: 28.32694198290507 min
# experiment: 6 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_5
# [250.0, 500.0, 1000.0, 2000.0, 4000.0, 8000.0]
# epoch:24, step:27500, 1.5313611,1.2336489,0.32490888,1.1147383,1.5634496,1.0452926, accept_ratio:0.5869565217391303, proba:0.3504641405740968
# time took: 28.12341352701187 min
# experiment: 7 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_6
# [250.0, 530.3300858899106, 1124.9999999999998, 2386.485386504597, 5062.499999999998, 10739.184239270686]
# epoch:24, step:27500, 0.6610038,1.3493037,1.0536631,1.1816813,1.7856106,0.71416503, accept_ratio:0.5652173913043479, proba:0.6175223558753322
# time took: 28.021113057931263 min
# experiment: 8 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_7
# [250.0, 559.0169943749474, 1250.0000000000002, 2795.0849718747377, 6250.000000000001, 13975.424859373688]
# epoch:24, step:27500, 1.8155628,0.48119736,1.1700914,0.99274415,1.4165015,0.6574171, accept_ratio:0.6304347826086957, proba:0.15288094505306052
# time took: 28.00788871049881 min
# experiment: 9 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_8
# [250.0, 586.3019699779287, 1375.0, 3224.660834878608, 7562.500000000001, 17735.634591832346]
# epoch:24, step:27500, 1.9797161,0.71338236,0.9376754,0.2941633,0.4229751,0.30623236, accept_ratio:0.45652173913043487, proba:0.4839230637937769
# time took: 28.118977304299673 min
# experiment: 10 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_9
# [250.0, 612.3724356957945, 1499.9999999999998, 3674.234614174766, 8999.999999999996, 22045.407685048594]
# epoch:24, step:27500, 0.63987684,0.61153984,1.0814267,1.0317807,0.81803596,1.3044716, accept_ratio:0.4999999999999998, proba:0.716019914493085
# time took: 27.90805960893631 min
# experiment: 11 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_10
# [250.0, 637.377439199098, 1624.9999999999998, 4142.953354794136, 10562.499999999996, 26929.196806161886]
# epoch:24, step:27500, 1.401009,1.9297137,0.20744489,0.29621518,0.32941356,0.36950448, accept_ratio:0.45652173913043476, proba:0.11239732084607139
# time took: 27.957754091421762 min
# experiment: 12 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_11
# [250.0, 661.4378277661477, 1750.0000000000002, 4630.064794363034, 12250.000000000002, 32410.453560541242]
# epoch:24, step:27500, 1.8014185,0.34551626,0.32706192,0.5235635,1.2744944,0.9474394, accept_ratio:0.4347826086956521, proba:0.29366472511021824
# time took: 27.751653718948365 min
# experiment: 13 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_12
# [250.0, 684.6531968814577, 1875.0, 5134.898976610933, 14062.5, 38511.742324581995]
# epoch:24, step:27500, 2.136863,0.5142122,0.773136,0.51150256,0.34322006,0.61512953, accept_ratio:0.45652173913043476, proba:0.4864902929344816
# time took: 27.705480233828226 min
# experiment: 14 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_13
# [250.0, 707.1067811865476, 2000.0000000000005, 5656.854249492381, 16000.000000000004, 45254.83399593906]
# epoch:24, step:27500, 2.0824356,0.4043122,0.9027383,0.8334961,0.33228582,0.5520506, accept_ratio:0.4347826086956522, proba:0.027284611308831933
# time took: 27.812005301316578 min
# experiment: 15 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_14
# [250.0, 728.8689868556626, 2125.0, 6195.386388273133, 18062.500000000004, 52660.78430032163]
# epoch:24, step:27500, 1.3516859,0.24695,1.9125316,0.9896535,0.80305594,0.40435162, accept_ratio:0.4130434782608694, proba:0.16385061446502475
# time took: 27.820972561836243 min
# experiment: 16 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_15
# [250.0, 750.0, 2250.0, 6750.0, 20250.0, 60750.0]
# epoch:24, step:27500, 2.124167,0.3780209,0.2969454,0.8383084,0.2407747,0.8700785, accept_ratio:0.391304347826087, proba:0.026187232556012543
# time took: 27.811786421140035 min
# experiment: 17 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_16
# [250.0, 770.551750371122, 2374.9999999999995, 7320.241628525659, 22562.499999999993, 69542.29547099373]
# epoch:24, step:27500, 1.1186174,0.32605502,1.7524371,0.22777583,0.6095979,0.49879062, accept_ratio:0.4130434782608695, proba:0.6519374465793861
# time took: 27.97582195599874 min
# experiment: 18 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_17
# [250.0, 790.5694150420949, 2500.0000000000005, 7905.69415042095, 25000.000000000007, 79056.9415042095]
# epoch:24, step:27500, 2.3531985,0.33343756,0.90093595,0.78675836,0.13456169,0.17956425, accept_ratio:0.47826086956521724, proba:0.8272655749575271
# time took: 27.92211046218872 min
# experiment: 19 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_18
# [250.0, 829.15619758885, 2750.0, 9120.71817347735, 30250.0, 100327.89990825084]
# epoch:24, step:27500, 1.0991981,0.28104195,1.8537449,0.47664955,0.11306292,0.46125934, accept_ratio:0.4565217391304347, proba:0.020123593510841368
# time took: 27.851164503892264 min
# experiment: 20 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_19
# [250.0, 866.0254037844386, 2999.9999999999995, 10392.304845413262, 35999.99999999999, 124707.65814495913]
# epoch:24, step:27500, 2.07585,0.27736822,0.35541433,0.841205,0.50218594,0.13603199, accept_ratio:0.34782608695652173, proba:0.6050223724673284
# time took: 27.995350241661072 min
# experiment: 21 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_20
# [250.0, 901.3878188659972, 3249.9999999999995, 11718.041645257965, 42249.99999999999, 152334.5413883535]
# epoch:24, step:27500, 2.0365458,0.8310741,0.16953434,0.39725927,0.4360125,0.38867033, accept_ratio:0.30434782608695654, proba:0.4694934332788575
# time took: 28.031753579775494 min
# experiment: 22 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_21
# [250.0, 935.4143466934853, 3500.0, 13095.800853708795, 49000.0, 183341.21195192312]
# epoch:24, step:27500, 0.98864746,1.752628,0.18849841,0.32963902,0.18652496,1.4290851, accept_ratio:0.41304347826086946, proba:0.06446696692199452
# time took: 27.92697250843048 min
# experiment: 23 / 23
# nn_mnist_tempfactor_PTLD_dynamic_6_information_250_22
# [250.0, 968.2458365518543, 3750.0000000000005, 14523.687548277814, 56250.00000000001, 217855.31322416724]
# epoch:24, step:27500, 2.1968458,0.4608507,0.72335327,0.12120105,0.18071257,0.17365697, accept_ratio:0.391304347826087, proba:0.7001508861983442
# time took: 27.896395206451416 min

# %%
"""CNN architecture"""
experiment_name = 'cnn_mnist_tempfactor_PTLD_dynamic_6_information_250'

tuning_parameter_name = 'temp_factor'
tuning_parameter_vals = [
                         np.sqrt(1.5), 
                         np.sqrt(2), 
                         np.sqrt(2.5), 
                         np.sqrt(3), 
                         np.sqrt(3.5),
                         np.sqrt(4),
                         np.sqrt(4.5),
                         np.sqrt(5),
                         np.sqrt(5.5),
                         np.sqrt(6),
                         np.sqrt(6.5),
                         np.sqrt(7),
                         np.sqrt(7.5),
                         np.sqrt(8),
                         np.sqrt(8.5),
                         np.sqrt(9),
                         np.sqrt(9.5),
                         np.sqrt(10),
                         np.sqrt(11),
                         np.sqrt(12),
                         np.sqrt(13),
                         np.sqrt(14),
                         np.sqrt(15)]

description = """Tuning of `temp_factor` with constant swap_attempt_step=600. 
Parralel Tempering Langevin Dynamics. 6 replicas
Tuning parameters values are """ + str(tuning_parameter_vals)
n_experiments= len(tuning_parameter_vals)
n_simulations = 15
batch_size = 50
n_epochs = 25
swap_attempt_step = 600
surface_view='information'




print(tuning_parameter_vals)
start_time = time()
for exp in range(n_experiments):
    print('experiment:', exp+1, '/', n_experiments)
    name = experiment_name + '_' + str(exp)

    print(name)
    temp_factor = tuning_parameter_vals[exp]
    noise_list = [beta_0*temp_factor**i for i in range(n_replicas)]

    print(noise_list)
    
    sim = Simulator(cnn_mnist_architecture2, 
                    0.001, 
                    noise_list, 
                    'betas',
                    batch_size=batch_size, 
                    n_epochs=n_epochs, 
                    name=name,
                    n_simulations=n_simulations, 
                    swap_attempt_step=swap_attempt_step, 
                    temp_factor=temp_factor, 
                    tuning_parameter_name=tuning_parameter_name,
                    surface_view=surface_view,
                    description=description)


    sim.train_n_times(sim.train_PTLD, train_data=train_data, train_labels=train_labels,
            test_data=test_data, test_labels=test_labels, 
            validation_data=valid_data, validation_labels=valid_labels)
    print()
    print('time took:', (time() - start_time)/60.0, 'min')
    start_time = time()
# Out:
# [1.224744871391589, 1.4142135623730951, 1.5811388300841898, 1.7320508075688772, 1.8708286933869707, 2.0, 2.1213203435596424, 2.23606797749979, 2.345207879911715, 2.449489742783178, 2.5495097567963922, 2.6457513110645907, 2.7386127875258306, 2.8284271247461903, 2.9154759474226504, 3.0, 3.082207001484488, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 3.872983346207417]
# experiment: 1 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_0
# [250.0, 306.18621784789724, 374.99999999999994, 459.2793267718458, 562.4999999999998, 688.9189901577686]
# epoch:24, step:27500, 0.7171805,0.4984631,0.66860545,0.81341314,0.62925756,0.69649947, accept_ratio:1.0, proba:0.9951127175121914          04253
# time took: 56.57723640203476 min
# experiment: 2 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_1
# [250.0, 353.5533905932738, 500.0000000000001, 707.1067811865477, 1000.0000000000002, 1414.2135623730956]
# epoch:24, step:27500, 0.45938239,0.4832917,0.47170967,0.6037269,0.50023925,0.62338537, accept_ratio:0.9130434782608694, proba:1.0140170564844948
# time took: 56.52412077585856 min
# experiment: 3 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_2
# [250.0, 395.28470752104744, 625.0000000000001, 988.2117688026187, 1562.5000000000005, 2470.529422006547]
# epoch:24, step:27500, 0.40336782,0.35399863,0.38734052,0.42397168,0.89416504,0.44695088, accept_ratio:0.9347826086956519, proba:0.9257079992043763
# time took: 56.59422890345255 min
# experiment: 4 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_3
# [250.0, 433.0127018922193, 749.9999999999999, 1299.0381056766578, 2249.9999999999995, 3897.114317029973]
# epoch:24, step:27500, 0.2908954,0.54368234,0.53462595,0.51315194,0.41387564,0.76660496, accept_ratio:0.8913043478260867, proba:0.8718056750490258
# time took: 56.51988756656647 min
# experiment: 5 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_4
# [250.0, 467.70717334674265, 875.0, 1636.9751067135994, 3062.5, 5729.4128734975975]
# epoch:24, step:27500, 0.3555235,0.2692258,0.35566592,0.6067347,0.37363797,0.5972906, accept_ratio:0.7391304347826085, proba:0.6922358404638769
# time took: 56.190261244773865 min
# experiment: 6 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_5
# [250.0, 500.0, 1000.0, 2000.0, 4000.0, 8000.0]
# epoch:24, step:27500, 0.35564852,0.39736068,0.75555766,0.6335514,0.65152293,0.56334656, accept_ratio:0.6956521739130435, proba:0.6902220211351477
# time took: 55.95836488008499 min
# experiment: 7 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_6
# [250.0, 530.3300858899106, 1124.9999999999998, 2386.485386504597, 5062.499999999998, 10739.184239270686]
# epoch:24, step:27500, 0.4868334,0.8722326,0.18952581,0.7996328,0.37177804,0.36066124, accept_ratio:0.5434782608695654, proba:0.5071622020706351
# time took: 56.059069939454396 min
# experiment: 8 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_7
# [250.0, 559.0169943749474, 1250.0000000000002, 2795.0849718747377, 6250.000000000001, 13975.424859373688]
# epoch:24, step:27500, 0.26996002,0.26343656,0.24283037,0.32663473,0.8846073,0.33852035, accept_ratio:0.5434782608695654, proba:0.8319088491242483
# time took: 56.05628419319789 min
# experiment: 9 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_8
# [250.0, 586.3019699779287, 1375.0, 3224.660834878608, 7562.500000000001, 17735.634591832346]
# epoch:24, step:27500, 0.5131539,0.74849993,0.17843817,0.581183,0.24994749,0.27014166, accept_ratio:0.5217391304347826, proba:0.5873355242724579
# time took: 55.60352286497752 min
# experiment: 10 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_9
# [250.0, 612.3724356957945, 1499.9999999999998, 3674.234614174766, 8999.999999999996, 22045.407685048594]
# epoch:24, step:27500, 0.46155497,0.18623957,0.21647356,0.83505994,0.32850796,0.4175838, accept_ratio:0.6304347826086956, proba:0.6243437321065436
# time took: 55.39046549797058 min
# experiment: 11 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_10
# [250.0, 637.377439199098, 1624.9999999999998, 4142.953354794136, 10562.499999999996, 26929.196806161886]
# epoch:24, step:27500, 0.32331288,0.22417735,0.26312536,0.5108439,0.32904074,0.7559964, accept_ratio:0.7173913043478262, proba:0.3606638210222274
# time took: 55.341907771428424 min
# experiment: 12 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_11
# [250.0, 661.4378277661477, 1750.0000000000002, 4630.064794363034, 12250.000000000002, 32410.453560541242]
# epoch:24, step:27500, 0.33795023,0.24059649,0.1992915,0.48780215,0.35013783,0.84037596, accept_ratio:0.5869565217391304, proba:0.6376807275507625
# time took: 55.21245888074239 min
# experiment: 13 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_12
# [250.0, 684.6531968814577, 1875.0, 5134.898976610933, 14062.5, 38511.742324581995]
# epoch:24, step:27500, 0.28531167,0.21003349,0.8731758,0.348505,0.8445531,0.68689, accept_ratio:0.5869565217391303, proba:1.073752708011639
# time took: 54.95303390820821 min
# experiment: 14 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_13
# [250.0, 707.1067811865476, 2000.0000000000005, 5656.854249492381, 16000.000000000004, 45254.83399593906]
# epoch:24, step:27500, 0.48990634,0.93491894,0.31747532,0.1595041,0.2550999,0.20436378, accept_ratio:0.5434782608695652, proba:0.4874136780586181
# time took: 54.902768516540526 min
# experiment: 15 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_14
# [250.0, 728.8689868556626, 2125.0, 6195.386388273133, 18062.500000000004, 52660.78430032163]
# epoch:24, step:27500, 0.31605518,0.19506301,0.85934806,0.3869885,0.41023883,0.83295196, accept_ratio:0.49999999999999994, proba:0.2200845964007926
# time took: 55.449345548947655 min
# experiment: 16 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_15
# [250.0, 750.0, 2250.0, 6750.0, 20250.0, 60750.0]
# epoch:24, step:27500, 0.60418177,0.18878336,0.4172793,0.4008914,0.2588299,0.27525526, accept_ratio:0.5217391304347826, proba:0.19252078652615695
# time took: 55.558006687959036 min
# experiment: 17 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_16
# [250.0, 770.551750371122, 2374.9999999999995, 7320.241628525659, 22562.499999999993, 69542.29547099373]
# epoch:24, step:27500, 0.43230385,0.8269617,0.1522675,0.20237905,0.19023691,0.26138312, accept_ratio:0.4130434782608696, proba:0.26447160659095426
# time took: 55.450495568911236 min
# experiment: 18 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_17
# [250.0, 790.5694150420949, 2500.0000000000005, 7905.69415042095, 25000.000000000007, 79056.9415042095]
# epoch:24, step:27500, 0.36851636,0.3689722,0.7171594,0.15442783,0.16403662,0.20133677, accept_ratio:0.565217391304348, proba:0.8224281074598161
# time took: 55.650481061140695 min
# experiment: 19 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_18
# [250.0, 829.15619758885, 2750.0, 9120.71817347735, 30250.0, 100327.89990825084]
# epoch:24, step:27500, 0.43379307,0.4777165,0.1657999,0.88771105,0.30798793,0.27480784, accept_ratio:0.43478260869565233, proba:0.4559901229816863
# time took: 55.43087344964345 min
# experiment: 20 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_19
# [250.0, 866.0254037844386, 2999.9999999999995, 10392.304845413262, 35999.99999999999, 124707.65814495913]
# epoch:24, step:27500, 0.39227676,0.14800043,0.8555093,0.20989405,0.21128532,0.20165822, accept_ratio:0.41304347826086957, proba:0.6936044345673016
# time took: 55.655083270867664 min
# experiment: 21 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_20
# [250.0, 901.3878188659972, 3249.9999999999995, 11718.041645257965, 42249.99999999999, 152334.5413883535]
# epoch:24, step:27500, 0.23671243,0.864786,0.15656494,0.84522265,0.7603626,0.23813134, accept_ratio:0.45652173913043476, proba:0.8032906640587975
# time took: 55.587490391731265 min
# experiment: 22 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_21
# [250.0, 935.4143466934853, 3500.0, 13095.800853708795, 49000.0, 183341.21195192312]
# epoch:24, step:27500, 0.8156054,0.300967,0.16397159,0.16698135,0.33250543,0.21618071, accept_ratio:0.43478260869565205, proba:0.6235312009924348
# time took: 55.41155318419138 min
# experiment: 23 / 23
# cnn_mnist_tempfactor_PTLD_dynamic_6_information_250_22
# [250.0, 968.2458365518543, 3750.0000000000005, 14523.687548277814, 56250.00000000001, 217855.31322416724]
# epoch:24, step:27500, 0.31753224,0.2887509,0.20772853,0.8974637,0.25058684,0.35430884, accept_ratio:0.39130434782608686, proba:0.5299263246110051
# time took: 55.44775739510854 min

# %%
# Out:
#   File "<ipython-input-18-82eddc4252ed>", line 1
#     '
#      ^
# SyntaxError: EOL while scanning string literal
